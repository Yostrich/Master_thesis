# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xdd\x07\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c4TSS_LUZ19_one/TSS_seq_LUZ19_enriched_one.plus.fa.out\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x16)}\x94\x8c\x05_name\x94h\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c@TSS_LUZ19_one/structural_properties/LUZ19_one_curvature.plus.png\x94\x8c@TSS_LUZ19_one/structural_properties/LUZ19_one_curvature.plus.csv\x94\x8c@TSS_LUZ19_one/structural_properties/LUZ19_one_stability.plus.png\x94\x8c@TSS_LUZ19_one/structural_properties/LUZ19_one_stability.plus.csv\x94\x8cBTSS_LUZ19_one/structural_properties/LUZ19_one_bendability.plus.png\x94\x8cBTSS_LUZ19_one/structural_properties/LUZ19_one_bendability.plus.csv\x94e}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x05LUZ19\x94\x8c\x03one\x94\x8c\x04plus\x94e}\x94(h\x0c}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94b\x8c\x05phage\x94hH\x8c\x05ident\x94hI\x8c\x04sign\x94hJub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bhgK\x01hiK\x01hkhdub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c#logs/notebooks/LUZ19_one.plus.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bh}hzub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\x0bLUZ19.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list

def smooth(value_list, window):
    tempList = value_list + [0]*6
    print(tempList)
    newList = []
    for i in range(0, len(value_list)):
        end = i+window
        Sum = sum(tempList[i:end])/window
        newList.append(Sum)
    return newList

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
    df[str(result.name)] = result.curvature[0,:]
    df[str(result.name)] = df[str(result.name)].rolling(20).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[0])
    df.to_csv(snakemake.output[1], index=True)
else:
    plt.savefig(snakemake.output[0])
    plt.show()
    df.to_csv(snakemake.output[1], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTodiValues(sequence, 'stability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[2])
    df.to_csv(snakemake.output[3], index=True)
else:
    plt.savefig(snakemake.output[2])
    plt.show()
    df.to_csv(snakemake.output[3], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTotriValues(sequence, 'DNAse1_bendability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(50).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[4])
    df.to_csv(snakemake.output[5], index=True)
else:
    plt.savefig(snakemake.output[4])
    plt.show()
    df.to_csv(snakemake.output[5], index=True)
# Out:
# GGT
# GTC
# TCT
# CTG
# TGT
# GTA
# TAG
# AGA
# GAG
# AGT
# GTT
# TTC
# TCG
# CGC
# GCC
# CCC
# CCT
# CTG
# TGT
# GTC
# TCT
# CTT
# TTC
# TCA
# CAC
# ACG
# CGC
# GCA
# CAA
# AAC
# ACA
# CAA
# AAC
# ACG
# CGC
# GCC
# CCT
# CTC
# TCT
# CTA
# TAC
# ACA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGC
# GCC
# CCT
# CTG
# TGG
# GGA
# GAG
# AGA
# GAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACA
# CAC
# ACA
# CAC
# ACT
# CTG
# TGC
# GCC
# CCA
# CAG
# AGG
# GGG
# GGC
# GCA
# CAT
# ATC
# TCG
# CGG
# GGT
# GTA
# TAG
# AGA
# GAG
# AGT
# GTA
# TAC
# ACG
# CGC
# GCA
# CAG
# AGC
# GCC
# CCA
# CAG
# AGA
# GAA
# AAC
# ACG
# CGA
# GAC
# ACG
# CGG
# GGG
# GGA
# GAG
# AGA
# GAT
# ATT
# TTG
# TGC
# GCA
# CAA
# AAC
# ACC
# CCT
# CTT
# TTC
# TCC
# CCA
# CAA
# AAG
# AGC
# GCG
# CGC
# GCG
# CGG
# GGC
# GCA
# CAC
# ACA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAT
# ATA
# TAG
# AGG
# GGC
# GCG
# CGC
# GCA
# CAA
# AAG
# AGG
# GGG
# GGA
# GAC
# ACA
# CAC
# ACG
# CGG
# GGC
# GCA
# CAA
# AAA
# AAC
# ACT
# CTC
# TCT
# CTT
# TTA
# TAG
# AGG
# GGG
# GGC
# GCA
# CAG
# AGG
# GGA
# GAA
# AAC
# ACC
# CCG
# CGC
# GCA
# CAG
# AGT
# GTG
# TGT
# GTG
# TGT
# GTA
# TAA
# AAG
# AGG
# GGC
# GCC
# CCG
# CGG
# GGC
# GCA
# GAC
# ACA
# CAC
# ACG
# CGG
# GGC
# GCA
# CAA
# AAA
# AAC
# ACT
# CTC
# TCT
# CTT
# TTA
# TAG
# AGG
# GGG
# GGC
# GCA
# CAG
# AGG
# GGA
# GAA
# AAC
# ACC
# CCG
# CGC
# GCA
# CAG
# AGT
# GTG
# TGT
# GTG
# TGT
# GTA
# TAA
# AAG
# AGG
# GGC
# GCC
# CCG
# CGG
# GGC
# GCA
# CAG
# AGG
# GGC
# GCA
# CAT
# ATC
# TCG
# CGC
# GCT
# CTG
# TGA
# GAG
# AGG
# GGG
# GGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAC
# ACA
# CAC
# ACG
# CGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGG
# GGA
# GAC
# ACA
# CAC
# ACG
# CGC
# GCG
# CGG
# GGT
# GTA
# TAC
# ACA
# CAG
# AGT
# GTT
# TTC
# TCG
# CGC
# GCA
# CAC
# ACC
# CCA
# CAC
# ACC
# CCT
# CTG
# TGA
# GAT
# ATG
# TGG
# GGC
# GCC
# CCA
# CAC
# ACT
# CTC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAA
# AAA
# AAG
# AGG
# GGG
# GGC
# GCC
# CCT
# CTA
# TAT
# ATG
# TGC
# GCC
# CCA
# CAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTG
# TGG
# GGA
# GAC
# ACG
# CGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATC
# TCC
# CCC
# CCC
# CCG
# CGA
# GAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAC
# ACA
# CAA
# AAG
# AGA
# GAC
# ACA
# CAA
# AAG
# AGC
# GCG
# CGC
# GCA
# CAA
# AAG
# AGT
# GTC
# TCT
# CTC
# TCT
# CTA
# TAA
# AAC
# ACA
# CAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# TGA
# GAT
# ATG
# TGG
# GGC
# GCC
# CCA
# CAC
# ACT
# CTC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAA
# AAA
# AAG
# AGG
# GGG
# GGC
# GCC
# CCT
# CTA
# TAT
# ATG
# TGC
# GCC
# CCA
# CAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTG
# TGG
# GGA
# GAC
# ACG
# CGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATC
# TCC
# CCC
# CCC
# CCG
# CGA
# GAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAC
# ACA
# CAA
# AAG
# AGA
# GAC
# ACA
# CAA
# AAG
# AGC
# GCG
# CGC
# GCA
# CAA
# AAG
# AGT
# GTC
# TCT
# CTC
# TCT
# CTA
# TAA
# AAC
# ACA
# CAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAG
# AGA
# GAC
# ACG
# CGA
# GAA
# AAA
# AAG
# AGG
# GGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTC
# TCA
# CAG
# AGC
# GCC
# CCA
# CAT
# ATC
# TCT
# CTG
# TGG
# GGC
# GCG
# CGG
# GGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGT
# GTT
# TTC
# TCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCG
# CGG
# GGA
# GAA
# AAC
# ACA
# CAT
# ATG
# TGG
# GGA
# GAC
# ACT
# CTG
# TGG
# GGT
# GTG
# TGC
# GCG
# CGG
# GGT
# GTA
# TAG
# AGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACC
# CCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTG
# TGG
# GGT
# GTT
# TTA
# TAG
# AGG
# GGT
# GTT
# TTC
# TCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCG
# CGG
# GGA
# GAA
# AAC
# ACA
# CAT
# ATG
# TGG
# GGA
# GAC
# ACT
# CTG
# TGG
# GGT
# GTG
# TGC
# GCG
# CGG
# GGT
# GTA
# TAG
# AGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACC
# CCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTG
# TGG
# GGT
# GTT
# TTA
# TAG
# AGG
# GGC
# GCA
# CAG
# AGG
# GGG
# GGT
# GTC
# TCC
# CCC
# CCA
# CAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATA
# TAC
# ACC
# CCT
# CTG
# TGT
# GTC
# TCG
# CGG
# GGG
# GGT
# GTG
# TGC
# GCT
# CTG
# TGA
# GAA
# AAG
# AGA
# GAC
# ACT
# CTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTG
# TGA
# GAG
# AGC
# GCG
# CGG
# GGG
# GGA
# GAA
# AAG
# AGC
# GCC
# CCT
# CTC
# TCC
# CCC
# CCC
# CCG
# CGT
# GTC
# TCC
# CCA
# CAC
# ACG
# CGG
# GGT
# GTT
# TTA
# TAA
# AAG
# AGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGC
# GCA
# CAC
# ACG
# CGT
# GTT
# TTA
# TAG
# AGT
# GTG
# TGC
# GCC
# CCG
# CGG
# GGT
# GTG
# TGG
# GGG
# GGA
# GAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTG
# TGT
# GTC
# TCA
# CAG
# AGT
# GTG
# TGG
# GGG
# GGA
# GAT
# ATC
# TCG
# CGA
# TGG
# GGA
# GAC
# ACT
# CTG
# TGG
# GGT
# GTG
# TGC
# GCG
# CGG
# GGT
# GTA
# TAG
# AGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACC
# CCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTG
# TGG
# GGT
# GTT
# TTA
# TAG
# AGG
# GGC
# GCA
# CAG
# AGG
# GGG
# GGT
# GTC
# TCC
# CCC
# CCA
# CAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATA
# TAC
# ACC
# CCT
# CTG
# TGT
# GTC
# TCG
# CGG
# GGG
# GGT
# GTG
# TGC
# GCT
# CTG
# TGA
# GAA
# AAG
# AGA
# GAC
# ACT
# CTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTG
# TGA
# GAG
# AGC
# GCG
# CGG
# GGG
# GGA
# GAA
# AAG
# AGC
# GCC
# CCT
# CTC
# TCC
# CCC
# CCC
# CCG
# CGT
# GTC
# TCC
# CCA
# CAC
# ACG
# CGG
# GGT
# GTT
# TTA
# TAA
# AAG
# AGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGC
# GCA
# CAC
# ACG
# CGT
# GTT
# TTA
# TAG
# AGT
# GTG
# TGC
# GCC
# CCG
# CGG
# GGT
# GTG
# TGG
# GGG
# GGA
# GAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTG
# TGT
# GTC
# TCA
# CAG
# AGT
# GTG
# TGG
# GGG
# GGA
# GAT
# ATC
# TCG
# CGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTA
# TAG
# AGA
# GAA
# AAA
# AAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGT
# GTT
# TTA
# TAA
# AAT
# ATC
# TCG
# CGC
# GCG
# CGA
# GTT
# TTA
# TAA
# AAG
# AGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGC
# GCA
# CAC
# ACG
# CGT
# GTT
# TTA
# TAG
# AGT
# GTG
# TGC
# GCC
# CCG
# CGG
# GGT
# GTG
# TGG
# GGG
# GGA
# GAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTG
# TGT
# GTC
# TCA
# CAG
# AGT
# GTG
# TGG
# GGG
# GGA
# GAT
# ATC
# TCG
# CGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTA
# TAG
# AGA
# GAA
# AAA
# AAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGT
# GTT
# TTA
# TAA
# AAT
# ATC
# TCG
# CGC
# GCG
# CGA
# GAC
# ACT
# CTG
# TGA
# GAC
# ACA
# CAG
# AGT
# GTA
# TAT
# ATG
# TGC
# GCT
# CTG
# TGG
# GGG
# GGT
# GTA
# TAG
# AGT
# GTA
# TAT
# ATC
# TCG
# CGG
# GGC
# GCG
# CGG
# GGG
# GGC
# GCC
# CCG
# CGA
# GAT
# ATT
# TTG
# TGA
# GAA
# AAC
# ACA
# CAA
# AAG
# AGG
# GGC
# GCC
# CCA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCG
# CGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGG
# GGT
# GTA
# TAC
# ACG
# CGG
# GGG
# GGG
# GGG
# GGA
# GAT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGC
# GCT
# CTG
# TGA
# GAC
# ACG
# CGA
# GAT
# ATC
# TCC
# CCC
# CCG
# CGA
# GAA
# AAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGG
# GGA
# GAC
# ACA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAG
# AGA
# GAA
# AAC
# GTG
# TGG
# GGG
# GGA
# GAT
# ATC
# TCG
# CGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTA
# TAG
# AGA
# GAA
# AAA
# AAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGT
# GTT
# TTA
# TAA
# AAT
# ATC
# TCG
# CGC
# GCG
# CGA
# GAC
# ACT
# CTG
# TGA
# GAC
# ACA
# CAG
# AGT
# GTA
# TAT
# ATG
# TGC
# GCT
# CTG
# TGG
# GGG
# GGT
# GTA
# TAG
# AGT
# GTA
# TAT
# ATC
# TCG
# CGG
# GGC
# GCG
# CGG
# GGG
# GGC
# GCC
# CCG
# CGA
# GAT
# ATT
# TTG
# TGA
# GAA
# AAC
# ACA
# CAA
# AAG
# AGG
# GGC
# GCC
# CCA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCG
# CGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGG
# GGT
# GTA
# TAC
# ACG
# CGG
# GGG
# GGG
# GGG
# GGA
# GAT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGC
# GCT
# CTG
# TGA
# GAC
# ACG
# CGA
# GAT
# ATC
# TCC
# CCC
# CCG
# CGA
# GAA
# AAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGG
# GGA
# GAC
# ACA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAG
# AGA
# GAA
# AAC
# ACC
# CCG
# CGC
# GCT
# CTG
# TGA
# GAT
# ATA
# TAC
# ACT
# CTA
# TAC
# ACA
# CAG
# AGG
# GGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATG
# TGC
# GCC
# CCA
# CAA
# AAT
# ATG
# TGC
# GCC
# CCA
# CAA
# AAG
# AGG
# GGT
# GTT
# TTT
# TTG
# TGT
# GTC
# TCC
# CCC
# CCT
# CTT
# TTG
# TGA
# TAT
# ATA
# TAG
# AGA
# GAG
# AGG
# GGC
# GCT
# CTA
# TAC
# ACC
# CCC
# CCC
# CCG
# CGC
# GCC
# CCC
# CCC
# CCG
# CGG
# GGA
# GAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATC
# TCG
# CGT
# GTT
# TTG
# TGA
# GAA
# AAT
# ATC
# TCT
# CTG
# TGG
# GGA
# GAG
# AGG
# GGC
# GCT
# CTG
# TGT
# GTA
# TAC
# ACG
# CGG
# GGG
# GGA
# GAC
# ACT
# CTC
# TCC
# CCT
# CTG
# TGG
# GGG
# GGC
# GCG
# CGT
# GTT
# TTC
# TCT
# CTT
# TTC
# TCT
# CTG
# TGC
# GCT
# CTG
# TGA
# GAG
# AGG
# GGC
# GCG
# CGG
# GGA
# GAT
# ATT
# TTA
# TAT
# ATG
# TGT
# GTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAC
# ACA
# CAT
# ATA
# TAG
# AGG
# GGA
# GAG
# AGC
# GCA
# CAA
# AAG
# AGT
# GTG
# TGC
# GCA
# CAT
# ATC
# TCC
# CCG
# CGT
# GTC
# TCC
# CCA
# CAA
# AAG
# AGG
# GGC
# GCC
# CCC
# CCT
# CTC
# TCG
# CGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGG
# GGA
# GAG
# AGC
# GCG
# CGG
# GGG
# GGG
# GGG
# GGA
# GAG
# AGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAG
# AGG
# GGT
# GTC
# TCA
# CAG
# AGG
# GGG
# GGA
# GAA
# AAG
# AGA
# GAC
# ACC
# CCT
# CTG
# TGG
# GGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAG
# AGG
# GGT
# GTG
# TGA
# GAA
# AAG
# AGA
# GAT
# ATG
# TGA
# GAG
# AGA
# GAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATG
# TGA
# GAC
# ACT
# CTA
# AGG
# GGG
# GGG
# GGG
# GGA
# GAT
# ATG
# TGA
# GAA
# AAG
# AGC
# GCA
# CAG
# AGC
# GCC
# CCC
# CCT
# CTT
# TTC
# TCG
# CGC
# GCG
# CGT
# GTG
# TGC
# GCT
# CTC
# TCC
# CCA
# CAG
# AGC
# GCA
# CAG
# AGT
# GTA
# TAC
# ACG
# CGG
# GGG
# GGA
# GAA
# AAG
# AGG
# GGA
# GAC
# ACG
# CGT
# GTG
# TGG
# GGA
# GAC
# ACT
# CTG
# TGG
# GGA
# GAC
# ACG
# CGC
# GCC
# CCA
# CAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGG
# GGC
# GCG
# CGC
# GCG
# CGG
# GGG
# GGT
# GTT
# TTC
# TCG
# CGC
# GCG
# CGG
# GGT
# GTT
# TTA
# TAT
# ATG
# TGT
# GTC
# TCA
# CAC
# ACA
# CAT
# ATA
# TAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAA
# AAG
# AGG
# GGA
# GAA
# AAC
# ACG
# CGC
# GCC
# CCC
# CCA
# CAA
# AAT
# ATC
# TCC
# CCA
# CAT
# ATG
# TGA
# GAA
# AAT
# ATT
# TTG
# TGG
# GGG
# GGG
# GGC
# GCG
# CGC
# GCC
# CCT
# CTG
# TGG
# GGA
# GAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGC
# GCA
# CAG
# AGA
# GAC
# ACG
# CGT
# GTT
# TTA
# TAA
# AAC
# ACA
# CAC
# ACC
# CCG
# CGT
# GTC
# TCA
# CAT
# ATG
# TGA
# GAA
# AAT
# ATA
# TAC
# ACC
# CCG
# CGC
# GCA
# CAC
# ACT
# CTG
# TGC
# GCG
# CGG
# GGA
# GAT
# ATC
# TCA
# CAT
# ATG
# TGG
# GGA
# GAC
# ACG
# CGA
# GAC
# ACT
# CTC
# TCA
# CAC
# ACT
# CTG
# TGC
# GCT
# CTG
# TGT
# GTA
# TAC

# %%
# Out:
# LUZ7 t5 plus
