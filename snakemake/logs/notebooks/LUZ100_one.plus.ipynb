# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xee\x07\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c6TSS_LUZ100_one/TSS_seq_LUZ100_enriched_one.plus.fa.out\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x16)}\x94\x8c\x05_name\x94h\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cBTSS_LUZ100_one/structural_properties/LUZ100_one_curvature.plus.png\x94\x8cBTSS_LUZ100_one/structural_properties/LUZ100_one_curvature.plus.csv\x94\x8cBTSS_LUZ100_one/structural_properties/LUZ100_one_stability.plus.png\x94\x8cBTSS_LUZ100_one/structural_properties/LUZ100_one_stability.plus.csv\x94\x8cDTSS_LUZ100_one/structural_properties/LUZ100_one_bendability.plus.png\x94\x8cDTSS_LUZ100_one/structural_properties/LUZ100_one_bendability.plus.csv\x94e}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x06LUZ100\x94\x8c\x03one\x94\x8c\x04plus\x94e}\x94(h\x0c}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94b\x8c\x05phage\x94hH\x8c\x05ident\x94hI\x8c\x04sign\x94hJub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bhgK\x01hiK\x01hkhdub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c$logs/notebooks/LUZ100_one.plus.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bh}hzub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\x0cLUZ100.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list

def smooth(value_list, window):
    tempList = value_list + [0]*6
    print(tempList)
    newList = []
    for i in range(0, len(value_list)):
        end = i+window
        Sum = sum(tempList[i:end])/window
        newList.append(Sum)
    return newList

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
    df[str(result.name)] = result.curvature[0,:]
    df[str(result.name)] = df[str(result.name)].rolling(20).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[0])
    df.to_csv(snakemake.output[1], index=True)
else:
    plt.savefig(snakemake.output[0])
    plt.show()
    df.to_csv(snakemake.output[1], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTodiValues(sequence, 'stability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[2])
    df.to_csv(snakemake.output[3], index=True)
else:
    plt.savefig(snakemake.output[2])
    plt.show()
    df.to_csv(snakemake.output[3], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTotriValues(sequence, 'DNAse1_bendability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(50).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[4])
    df.to_csv(snakemake.output[5], index=True)
else:
    plt.savefig(snakemake.output[4])
    plt.show()
    df.to_csv(snakemake.output[5], index=True)
# Out:
# TAG
# AGT
# GTG
# TGG
# GGT
# GTT
# TTC
# TCC
# CCC
# CCA
# CAT
# ATG
# TGC
# GCA
# CAG
# AGT
# GTC
# TCA
# CAC
# ACA
# CAC
# ACC
# CCA
# CAC
# ACA
# CAA
# AAG
# AGA
# GAT
# ATA
# TAT
# ATA
# TAG
# AGC
# GCG
# CGT
# GTT
# TTA
# TAT
# ATG
# TGC
# GCC
# CCT
# CTA
# TAC
# ACC
# CCT
# CTT
# TTC
# TCA
# CAC
# ACG
# CGC
# GCA
# CAA
# AAA
# AAA
# AAG
# AGA
# GAC
# ACT
# CTT
# TTG
# TGA
# GAC
# ACA
# CAT
# ATC
# TCC
# CCT
# CTA
# TAT
# ATC
# TCC
# CCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCG
# CGC
# GCA
# CAT
# ATA
# TAA
# AAG
# AGA
# GAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGC
# GCC
# CCA
# CAT
# ATG
# TGG
# GGA
# GAC
# ACG
# CGG
# GGT
# GTC
# TCA
# CAT
# ATC
# TCT
# CTA
# TAG
# AGC
# GCG
# CGG
# GGC
# GCC
# CCT
# CTT
# TTC
# TCC
# CCA
# CAG
# AGC
# GCC
# CCC
# CCA
# CAG
# AGC
# GCC
# CCC
# CCC
# CCA
# CAA
# AAG
# AGC
# GCG
# CGC
# GCT
# CTG
# TGA
# GAA
# AAC
# ACA
# CAG
# AGT
# GTC
# TCA
# CAA
# AAG
# AGG
# GGA
# GAT
# ATA
# TAA
# AAA
# AAG
# AGA
# GAC
# ACG
# CGT
# GTT
# TTA
# TAA
# AAA
# AAA
# AAC
# ACC
# CCC
# CCG
# CGC
# GCG
# CGT
# GTA
# TAG
# AGC
# GCA
# CAC
# ACT
# CTA
# TAG
# AGG
# GGG
# GGG
# GGC
# GCG
# CGC
# GCA
# CAG
# AGC
# GCA
# CAC
# ACT
# CTG
# TGA
# GAC
# ACC
# CTG
# TGG
# GGT
# GTA
# TAC
# ACA
# CAG
# AGC
# GCC
# CCT
# CTC
# TCA
# CAA
# AAA
# AAC
# ACG
# CGG
# GGT
# GTC
# TCA
# CAA
# AAG
# AGG
# GGC
# GCC
# CCA
# CAG
# AGA
# GAC
# ACG
# CGA
# GAT
# ATA
# TAC
# ACA
# CAG
# AGA
# GAC
# ACT
# CTG
# TGC
# GCA
# CAG
# AGG
# GGG
# GGC
# GCG
# CGA
# GAT
# ATC
# TCC
# CCA
# CAA
# AAA
# AAA
# AAG
# AGC
# GCC
# CCG
# CGC
# GCT
# CTT
# TTG
# TGA
# GAC
# ACA
# CAA
# AAA
# AAC
# ACT
# CTA
# TAT
# ATC
# TCC
# CCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCG
# CGC
# GCA
# CAT
# ATA
# TAA
# AAG
# AGA
# GAT
# ATG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGA
# GAG
# AGG
# GGG
# GGA
# GAA
# AAG
# AGC
# GCG
# CGA
# GAA
# AAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAC
# ACC
# CCT
# CTC
# TCA
# CAC
# ACC
# CCG
# CGA
# GAC
# ACC
# CCT
# CTT
# TTC
# TCG
# CGG
# GGG
# GGT
# GTC
# TCA
# CAC
# ACT
# CTG
# TGC
# GCT
# CTC
# TCT
# CTT
# TTT
# TTA
# TAA
# AAC
# ACA
# CAA
# AAT
# ATC
# TCT
# CTG
# TGG
# GGA
# GAT
# ATG
# TGA
# GAT
# ATG
# TGG
# GGT
# GTG
# TGC
# GCC
# CCC
# CCG
# CGT
# GTA
# TAG
# AGG
# GGT
# GTA
# TAA
# AAC
# ACA
# CAC
# ACA
# CAA
# AAA
# AAC
# ACG
# CGG
# GGC
# GCA
# CAA
# AAG
# AGG
# GGA
# GAT
# ATT
# TTG
# TGC
# GCC
# CCG
# CGG
# ATC
# TCT
# CTT
# TTC
# TCG
# CGG
# GGA
# GAA
# AAA
# AAG
# AGC
# GCG
# CGG
# GGT
# GTG
# TGC
# GCT
# CTT
# TTT
# TTT
# TTT
# TTT
# TTG
# TGA
# GAG
# AGT
# GTT
# TTC
# TCG
# CGA
# GAT
# ATA
# TAG
# AGT
# GTA
# TAA
# AAT
# ATT
# TTC
# TCA
# CAC
# ACG
# CGT
# GTC
# TCC
# CCG
# CGC
# GCA
# CAA
# AAC
# ACA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCT
# CTA
# TAG
# AGA
# GAC
# ACT
# CTG
# TGG
# GGA
# GAT
# ATT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAA
# AAC
# ACC
# CCG
# CGA
# GAA
# AAT
# ATG
# TGA
# GAT
# ATG
# TGT
# GTT
# TTT
# TTT
# TTA
# TAC
# ACT
# CTG
# TGT
# GTG
# TGG
# GGG
# GGT
# GTG
# TGT
# GTG
# TGG
# GGA
# GAG
# AGG
# GGT
# GTT
# TTC
# TCC
# CCA
# CAC
# ACA
# CAT
# ATC
# TCG
# CGT
# GTC
# TCA
# CAT
# ATA
# TAT
# ATC
# TCC
# CCA
# CAA
# AAA
# AAG
# AGA
# GAA
# AAA
# AAC
# ACT
# CTA
# TAG
# AGG
# GGA
# GAG
# AGG
# GGT
# GTA
# TAA
# AAC
# ACA
# CAA
# AAA
# AAC
# ACC
# CCA
# CAT
# ATG
# TGG
# GGC
# GCT
# CTC
# TCT
# CTG
# TGA
# GAC
# ACA
# CAG
# AGC
# GCT
# CTC
# TCT
# CTC
# TCG
# CGC
# GCA
# CAG
# AGT
# GTG
# TGA
# GAT
# ATC
# TCG
# CGA
# GAG
# AGG
# GGA
# GAA
# AAG
# AGT
# GTA
# TAC
# ACT
# CTC
# TCA
# CAA
# AAG
# AGC
# GCG
# CGG
# GGT
# GTT
# TTC
# TCC
# CCG
# CGC
# GCG
# CGA
# ACT
# CTG
# TGT
# GTC
# TCG
# CGC
# GCA
# CAA
# AAC
# ACC
# CCT
# CTT
# TTT
# TTG
# TGC
# GCA
# CAG
# AGA
# GAC
# ACC
# CCG
# CGC
# GCT
# CTC
# TCG
# CGA
# GAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGA
# GAC
# ACA
# CAC
# ACG
# CGA
# GAG
# AGC
# GCG
# CGG
# GGT
# GTT
# TTT
# TTG
# TGT
# GTG
# TGT
# GTC
# TCG
# CGT
# GTC
# TCA
# CAC
# ACG
# CGG
# GGC
# GCT
# CTC
# TCT
# CTC
# TCT
# CTG
# TGA
# GAC
# ACG
# CGC
# GCC
# CCC
# CCT
# CTG
# TGC
# GCT
# CTT
# TTG
# TGG
# GGC
# GCA
# CAA
# AAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGT
# GTC
# TCT
# CTT
# TTG
# TGG
# GGA
# GAG
# AGC
# GCA
# CAC
# ACC
# CCG
# CGA
# GAG
# AGA
# GAG
# AGG
# GGT
# GTG
# TGA
# GAC
# ACC
# CCT
# CTC
# TCC
# CCG
# CGA
# GAG
# AGG
# GGC
# GCC
# CCG
# CGG
# GGT
# GTT
# TTC
# TCC
# CCT
# CTT
# TTA
# TAA
# AAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAA
# AAC
# ACT
# CTC
# TCA
# CAG
# AGA
# GAG
# AGA
# GAG
# AGA
# GAT
# ATC
# TCC
# CCA
# CAA
# AAT
# ATA
# TAG
# AGA
# GAT
# ATG
# TGA
# GAC
# ACT
# CTT
# TTC
# TCC
# CCA
# CAT
# ATC
# TCA
# CAT
# ATC
# TCA
# CAC
# ACC
# CCA
# CAA
# AAC
# ACC
# CCA
# CAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATT
# TTC
# TCA
# CAG
# AGG
# GGA
# GAA
# AAA
# AAT
# ATT
# TTG
# GTG
# TGC
# GCT
# CTG
# TGG
# GGA
# GAG
# AGT
# GTC
# TCC
# CCG
# CGC
# GCG
# CGT
# GTT
# TTC
# TCT
# CTT
# TTT
# TTT
# TTT
# TTT
# TTG
# TGC
# GCC
# CCT
# CTG
# TGA
# GAT
# ATA
# TAC
# ACA
# CAA
# AAT
# ATC
# TCC
# CCA
# CAC
# ACT
# CTA
# TAG
# AGC
# GCG
# CGC
# GCA
# CAT
# ATA
# TAG
# AGG
# GGT
# GTT
# TTG
# TGC
# GCG
# CGC
# GCA
# CAT
# ATG
# TGT
# GTG
# TGT
# GTA
# TAA
# AAC
# ACG
# CGT
# GTC
# TCG
# CGA
# GAG
# AGC
# GCC
# CCA
# CAG
# AGG
# GGC
# GCG
# CGG
# GGG
# GGA
# GAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGC
# GCG
# CGC
# GCT
# CTG
# TGG
# GGC
# GCT
# CTC
# TCC
# CCA
# CAC
# ACC
# CCC
# CCC
# CCC
# CCA
# CAA
# AAG
# AGG
# GGC
# GCG
# CGA
# GAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGC
# GCC
# CCC
# CCA
# CAC
# ACC
# CCC
# CCA
# CAC
# ACC
# CCA
# CAG
# AGA
# GAT
# ATC
# TCA
# CAC
# ACG
# CGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCA
# CAT
# ATG
# TGA
# GAG
# AGC
# GCG
# CGC
# GCA
# CAC
# ACT
# CTC
# TCG
# CGA
# GAC
# ACA
# CAG
# AGA
# GTG
# TGA
# GAA
# AAG
# AGG
# GGA
# GAC
# ACT
# CTG
# TGG
# GGT
# GTT
# TTC
# TCG
# CGA
# GAG
# AGA
# GAA
# AAG
# AGG
# GGA
# GAA
# AAG
# AGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCG
# CGA
# GAA
# AAG
# AGT
# GTA
# TAC
# ACC
# CCC
# CCC
# CCG
# CGA
# GAG
# AGG
# GGC
# GCC
# CCG
# CGC
# GCG
# CGT
# GTA
# TAC
# ACA
# CAT
# ATC
# TCC
# CCA
# CAG
# AGG
# GGC
# GCC
# CCG
# CGT
# GTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAT
# ATC
# TCT
# CTG
# TGA
# GAC
# ACC
# CCA
# CAA
# AAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGC
# GCC
# CCC
# CCC
# CCC
# CCG
# CGG
# GGT
# GTA
# TAT
# ATG
# TGC
# GCC
# CCC
# CCA
# CAG
# AGC
# GCG
# CGC
# GCT
# CTG
# TGC
# GCC
# CCG
# CGG
# GGG
# GGG
# GGG
# GGT
# GTT
# TTT
# TTC
# TCT
# CTG
# TGT
# GTT
# TTT
# TTC
# TCA
# CAA
# AAG
# AGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGA
# GAC
# ACA
# CAA
# AAC
# ACT
# CTG
# TGT
# GTG
# TGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCC
# CCC
# CCA
# CAT
# ATG
# TGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACA
# CAC
# ACC
# CCC
# CCA
# CAA
# AAA
# AAT
# ATC
# TCC
# CCG
# CGT
# GTG
# TGC
# GCT
# CTC
# TCT
# TCA
# CAA
# AAG
# AGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGA
# GAC
# ACA
# CAA
# AAC
# ACT
# CTG
# TGT
# GTG
# TGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCC
# CCC
# CCA
# CAT
# ATG
# TGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACA
# CAC
# ACC
# CCC
# CCA
# CAA
# AAA
# AAT
# ATC
# TCC
# CCG
# CGT
# GTG
# TGC
# GCT
# CTC
# TCT
# CTG
# TGT
# GTC
# TCC
# CCC
# CCC
# CCG
# CGC
# GCA
# CAA
# AAT
# ATG
# TGT
# GTG
# TGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATC
# TCC
# CCT
# CTG
# TGA
# GAA
# AAC
# ACC
# CCA
# CAC
# ACC
# CCT
# CTG
# TGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTG
# TGG
# GGC
# GCC
# CCA
# CAC
# ACA
# CAC
# ACG
# CGA
# GAT
# ATC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAG
# AGC
# GCG
# CGC
# GCT
# CTC
# TCG
# CGG
# GGC
# GCC
# CCC
# CCT
# CTG
# TGA
# GAT
# ATG
# TGG
# GGA
# GAC
# ACT
# CTT
# TTC
# TCG
# CGG
# GGC
# GCG
# CGT
# GTG
# TGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTC
# TCT
# CTG
# TGC
# GCC
# CCG
# CGC
# GCG
# CGC
# GCC
# CCG
# CGC
# GCA
# CAT
# ATC
# TCG
# CGC
# GCT
# CTG
# TGA
# GAC
# ACC
# CCT
# CTC
# TCA
# CAA
# AAG
# AGG
# GGA
# GAG
# AGC
# GCG
# CGT
# GTG
# TGG
# GGC
# GCT
# CTA
# TAC
# ACG
# CGA
# GAC
# ACA
# CAT
# ATC
# TCG
# CGT
# GTG
# TGT
# GTC
# TCC
# TGT
# GTA
# TAG
# AGA
# GAA
# AAC
# ACA
# CAT
# ATG
# TGG
# GGA
# GAT
# ATG
# TGT
# GTG
# TGA
# GAC
# ACT
# CTG
# TGA
# GAG
# AGG
# GGG
# GGG
# GGA
# GAG
# AGC
# GCA
# CAG
# AGG
# GGA
# GAG
# AGG
# GGC
# GCT
# CTC
# TCC
# CCT
# CTC
# TCT
# CTC
# TCG
# CGG
# GGT
# GTC
# TCT
# CTC
# TCT
# CTT
# TTT
# TTG
# TGC
# GCA
# CAA
# AAG
# AGA
# GAT
# ATC
# TCG
# CGC
# GCT
# CTG
# TGC
# GCA
# CAA
# AAG
# AGA
# GAT
# ATC
# TCG
# CGA
# GAC
# ACG
# CGA
# GAC
# ACG
# CGT
# GTT
# TTC
# TCA
# CAA
# AAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAG
# AGG
# GGA
# GAA
# AAA
# AAG
# AGG
# GGG
# GGG
# GGA
# GAA
# AAA
# AAA
# AAA
# AAG
# AGA
# GAA
# AAT
# ATA
# TAG
# AGG
# GGG
# GGA
# GAA
# AAA
# AAA
# AAA
# AAC
# ACT
# CTT
# TTA
# TAT
# ATT
# TTG
# TGA
# GAT
# ATT
# TTA
# TAC
# ACT
# CTT
# TTA
# TAT
# ATA
# TAG
# AGA
# GAT
# ATA
# TAC
# ACA
# CAG
# AGA
# GAC
# ACA
# CAC
# ACT
# CTA
# TAG
# AGA
# GAT
# ATC
# TCC
# CCT
# CTC
# TCT
# CTG
# TGT
# GTC
# TCA
# CAG
# AGA
# GAT
# ATG
# TGT
# GTC
# TCT
# CTG
# TGC
# GCT
# CTG
# TGC
# GCT
# CTT
# TTT
# TTC
# TCC
# CCC
# CCT
# CTC
# TCC
# CCA
# CAC
# ACT
# CTG
# TGA
# GAC
# ACC
# CCA
# CAT

# %%
# Out:
# LUZ7 t5 plus
