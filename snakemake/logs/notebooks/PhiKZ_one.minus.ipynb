# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xe6\x07\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c5TSS_PhiKZ_one/TSS_seq_PhiKZ_enriched_one.minus.fa.out\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x16)}\x94\x8c\x05_name\x94h\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cATSS_PhiKZ_one/structural_properties/PhiKZ_one_curvature.minus.png\x94\x8cATSS_PhiKZ_one/structural_properties/PhiKZ_one_curvature.minus.csv\x94\x8cATSS_PhiKZ_one/structural_properties/PhiKZ_one_stability.minus.png\x94\x8cATSS_PhiKZ_one/structural_properties/PhiKZ_one_stability.minus.csv\x94\x8cCTSS_PhiKZ_one/structural_properties/PhiKZ_one_bendability.minus.png\x94\x8cCTSS_PhiKZ_one/structural_properties/PhiKZ_one_bendability.minus.csv\x94e}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x05PhiKZ\x94\x8c\x03one\x94\x8c\x05minus\x94e}\x94(h\x0c}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94b\x8c\x05phage\x94hH\x8c\x05ident\x94hI\x8c\x04sign\x94hJub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bhgK\x01hiK\x01hkhdub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c$logs/notebooks/PhiKZ_one.minus.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bh}hzub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\x0bphiKZ.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list

def smooth(value_list, window):
    tempList = value_list + [0]*6
    print(tempList)
    newList = []
    for i in range(0, len(value_list)):
        end = i+window
        Sum = sum(tempList[i:end])/window
        newList.append(Sum)
    return newList

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
    df[str(result.name)] = result.curvature[0,:]
    df[str(result.name)] = df[str(result.name)].rolling(20).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[0])
    df.to_csv(snakemake.output[1], index=True)
else:
    plt.savefig(snakemake.output[0])
    plt.show()
    df.to_csv(snakemake.output[1], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTodiValues(sequence, 'stability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[2])
    df.to_csv(snakemake.output[3], index=True)
else:
    plt.savefig(snakemake.output[2])
    plt.show()
    df.to_csv(snakemake.output[3], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTotriValues(sequence, 'DNAse1_bendability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(50).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[4])
    df.to_csv(snakemake.output[5], index=True)
else:
    plt.savefig(snakemake.output[4])
    plt.show()
    df.to_csv(snakemake.output[5], index=True)
# Out:
# CTG
# TGT
# GTA
# TAT
# ATA
# TAT
# ATG
# TGA
# GAT
# ATA
# TAA
# AAT
# ATA
# TAA
# AAA
# AAA
# AAC
# ACT
# CTT
# TTT
# TTC
# TCC
# CCT
# CTA
# TAG
# AGG
# GGT
# GTT
# TTA
# TAC
# ACA
# CAT
# ATT
# TTG
# TGG
# GGC
# GCA
# CAA
# AAT
# ATG
# TGG
# GGT
# GTC
# TCA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGT
# GTA
# TAA
# AAA
# AAC
# ACA
# CAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTC
# TCT
# CTG
# TGA
# GAT
# ATG
# TGC
# GCT
# CTA
# TAA
# AAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCG
# CGT
# GTC
# TCT
# CTA
# TAA
# AAC
# ACT
# CTA
# TAT
# ATC
# TCA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAA
# AAT
# ATT
# TTC
# TCT
# CTA
# TAA
# AAC
# ACT
# CTC
# TCC
# CCA
# CAG
# AGT
# GTA
# TAA
# AAT
# ATC
# TCT
# CTT
# TTT
# TTT
# TTG
# TGT
# GTT
# TTC
# TCG
# CGC
# GCT
# CTA
# TAG
# AGA
# GAG
# AGT
# GTT
# TTG
# TGC
# GCT
# CTT
# TTA
# TAA
# AAC
# ACT
# CTT
# TTC
# TCA
# CAA
# AAA
# AAT
# ATA
# TAC
# ACC
# CCC
# CCT
# CTC
# TCT
# CTT
# TTC
# TCA
# CAT
# ATT
# TTG
# TGC
# GCG
# CGA
# GAA
# AAG
# AGA
# GAG
# AGG
# GGG
# GGT
# GTA
# TAA
# AAC
# ACG
# CGT
# GTA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTT
# TTT
# TTT
# TTT
# TTT
# TTT
# TTG
# TGT
# GTT
# TGG
# GGT
# GTT
# TTC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGC
# GCT
# CTT
# TTT
# TTA
# TAT
# ATT
# TTT
# TTG
# TGA
# GAC
# ACA
# CAT
# ATC
# TCT
# CTT
# TTG
# TGT
# GTT
# TTA
# TAT
# ATA
# TAC
# ACT
# CTC
# TCC
# CCG
# CGA
# GAT
# ATA
# TAG
# AGA
# GAG
# AGG
# GGC
# GCT
# CTT
# TTA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAT
# ATA
# TAT
# ATT
# TTT
# TTG
# TGC
# GCC
# CCA
# CAA
# AAT
# ATA
# TAT
# ATA
# TAA
# AAA
# AAT
# ATT
# TTG
# TGA
# GAC
# ACA
# CAA
# AAA
# AAT
# ATG
# TGA
# GAA
# AAA
# AAA
# AAA
# AAA
# AAT
# ATG
# TGA
# GAT
# ATT
# TTA
# TAG
# AGT
# GTT
# TTC
# TCA
# CAA
# AAC
# ACA
# CAT
# ATA
# TAT
# ATA
# TAT
# ATT
# TTT
# TTA
# TAA
# AAC
# ACA
# CAC
# ACA
# CAT
# ATT
# TTT
# TTG
# TGG
# GGT
# GTA
# TAA
# AAT
# ATT
# TTT
# TTT
# TTA
# TAC
# ACA
# CAC
# ACT
# CTA
# TAT
# ATA
# TAT
# ATT
# TTA
# TAA
# AAA
# AAG
# AGA
# GAA
# AAT
# ATA
# TAA
# AAC
# ACT
# CTA
# TAT
# ATC
# TCT
# CTG
# TGT
# GTC
# TCC
# CCA
# CAA
# AAC
# ACC
# CCC
# CCT
# CTA
# TAT
# ATG
# TGT
# GTT
# TTA
# TAA
# AAT
# ATA
# TAA
# AAT
# ATT
# TTC
# TCC
# CCG
# CGT
# GTA
# TAT
# ATA
# TAA
# AAA
# AAA
# AAA
# AAG
# AGG
# GGA
# GAT
# ATA
# TAT
# ATC
# TCG
# CGT
# GTC
# TCA
# CAT
# ATG
# TGA
# GAA
# AAA
# ATC
# TCC
# CCT
# CTA
# TAA
# AAT
# ATT
# TTA
# TAA
# AAT
# ATC
# TCT
# CTC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGC
# GCT
# CTA
# TAG
# AGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAA
# AAT
# ATA
# TAC
# ACC
# CCC
# CCG
# CGT
# GTT
# TTA
# TAT
# ATC
# TCA
# CAC
# ACT
# CTC
# TCG
# CGT
# GTT
# TTG
# TGA
# GAT
# ATA
# TAA
# AAT
# ATT
# TTG
# TGA
# GAT
# ATT
# TTT
# TTG
# TGT
# GTT
# TTT
# TTA
# TAT
# ATT
# TTA
# TAA
# AAC
# ACT
# CTA
# TAA
# AAT
# ATT
# TTT
# TTG
# TGA
# GAC
# ACT
# CTT
# TTA
# TAA
# AAT
# ATC
# TCA
# CAG
# AGA
# GAA
# AAT
# ATG
# TGA
# GAT
# ATC
# TCA
# CAA
# AAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTG
# TGT
# GTT
# TTA
# TAA
# AAT
# ATA
# TAA
# AAT
# ATC
# TCT
# CTA
# TAG
# AGT
# GTA
# TAT
# ATA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAG
# AGT
# GTA
# TAT
# ATC
# TCA
# CAT
# ATT
# TTG
# TGA
# GAG
# AGT
# GTA
# TAA
# AAT
# ATA
# TAC
# ACT
# CTG
# TGG
# GGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAA
# AAA
# AAT
# ATA
# TAT
# ATT
# TTA
# TAC
# ACT
# CTC
# TCA
# CAT
# ATG
# TGA
# GAA
# AAT
# ATC
# TCT
# CTT
# TTA
# TAC
# ACC
# CCT
# CTA
# TAA
# AAT
# ATG
# TGT
# GTG
# TGG
# GGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAG
# AGG
# GGA
# GAA
# AAT
# ATC
# TCG
# TCG
# CGA
# GAT
# ATT
# TTT
# TTT
# TTC
# TCT
# CTA
# TAA
# AAA
# AAC
# ACA
# CAT
# ATA
# TAA
# AAT
# ATA
# TAG
# AGA
# GAG
# AGT
# GTG
# TGA
# GAT
# ATA
# TAC
# ACA
# CAT
# ATG
# TGA
# GAA
# AAA
# AAC
# ACG
# CGA
# GAG
# AGT
# GTA
# TAA
# AAT
# ATT
# TTG
# TGT
# GTT
# TTT
# TTT
# TTG
# TGG
# GGA
# GAC
# ACT
# CTT
# TTG
# TGA
# GAC
# ACA
# CAT
# ATT
# TTT
# TTT
# TTT
# TTA
# TAT
# ATA
# TAG
# AGA
# GAT
# ATT
# TTT
# TTC
# TCC
# CCA
# CAA
# AAT
# ATT
# TTG
# TGT
# GTG
# TGA
# GAA
# AAA
# AAT
# ATT
# TTA
# TAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATG
# TGT
# GTA
# TAC
# ACA
# CAG
# AGT
# GTG
# TGT
# GTA
# TAT
# ATC
# TCA
# CAT
# ATT
# TTT
# TTA
# TAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCT
# CTA
# TAG
# AGT
# GTA
# TAA
# AAT
# ATT
# TTT
# TTT
# TTA
# TAG
# AGT
# GTG
# TGA
# GAA
# AAT
# ATG
# TGT
# GTA
# TAT
# ATT
# TTT
# TTG
# TGC
# GCT
# CTA
# TAT
# ATA
# TAT
# ATT
# TTG
# TGC
# GCT
# CTA
# TAT
# ATG
# TGT
# GTA
# TAG
# AGA
# GAC
# ACA
# CAG
# AGT
# GTT
# TTC
# TCC
# CCC
# CCA
# CAA
# AAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTA
# TAA
# AAA
# AAG
# AGT
# GTT
# TTA
# TAC
# ACA
# CAA
# AAT
# ATA
# TAT
# ATA
# TAG
# AGG
# GGT
# GTA
# TAC
# ACT
# CTT
# TTT
# TTC
# TCA
# CAC
# ACA
# CAA
# TGA
# GAA
# AAT
# ATA
# TAC
# ACC
# CCC
# CCC
# CCA
# CAA
# AAC
# ACC
# CCA
# CAG
# AGC
# GCT
# CTT
# TTT
# TTA
# TAC
# ACC
# CCC
# CCT
# CTG
# TGT
# GTC
# TCG
# CGG
# GGA
# GAA
# AAT
# ATG
# TGA
# GAT
# ATC
# TCC
# CCG
# CGT
# GTC
# TCA
# CAG
# AGT
# GTG
# TGT
# GTA
# TAT
# ATA
# TAA
# AAA
# AAA
# AAC
# ACC
# CCA
# CAT
# ATA
# TAC
# ACC
# CCG
# CGT
# GTC
# TCT
# CTG
# TGA
# GAC
# ACA
# CAT
# ATT
# TTA
# TAT
# ATT
# TTG
# TGT
# GTT
# TTT
# TTC
# TCC
# CCT
# CTC
# TCA
# CAT
# ATG
# TGT
# GTG
# TGA
# GAT
# ATC
# TCG
# CGA
# GAT
# ATT
# TTA
# TAC
# ACT
# CTA
# TAA
# AAA
# AAC
# ACT
# CTA
# TAG
# AGA
# GAT
# ATA
# TAA
# AAT
# ATA
# TAA
# AAT
# ATT
# TTC
# TCT
# CTA
# TAG
# AGC
# GCA
# CAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAT
# ATT
# TTA
# TAC
# ACT
# CTC
# TCA
# CAT
# ATC
# TCA
# CAC
# ACA
# CAC
# ACT
# CTT
# TTT
# TTG
# TGC
# GCA
# CAC
# ACG
# CGC
# GCC
# CCA
# CAT
# ATT
# TTC
# TCT
# CTT
# TTC
# TCA
# CAT
# ATA
# TAT
# ATG
# TGC
# GCT
# CTT
# TTG
# TGC
# GCT
# CTC
# TCA
# CAA
# AAT
# ATT
# TTT
# TTT
# TTA
# TAG
# AGC
# GCG
# CGC
# GCG
# CGC
# GCT
# CTC
# TCA
# CAG
# AGA
# GAT
# ATA
# TAC
# ACA
# CAA
# AAT
# ATA
# TAT
# ATG
# TGT
# GTG
# TGA
# GAC
# ACT
# CTT
# TTT
# TTA
# TTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAC
# ACT
# CTA
# TAC
# ACA
# CAG
# AGT
# GTT
# TTG
# TGT
# GTT
# TTT
# TTT
# TTA
# TAA
# AAC
# ACA
# CAT
# ATA
# TAC
# ACA
# CAT
# ATC
# TCT
# CTT
# TTA
# TAC
# ACA
# CAG
# AGG
# GGG
# GGG
# GGA
# GAT
# ATA
# TAG
# AGA
# GAG
# AGC
# GCT
# CTA
# TAT
# ATT
# TTG
# TGT
# GTA
# TAG
# AGT
# GTT
# TTT
# TTT
# TTC
# TCT
# CTA
# TAC
# ACA
# CAG
# AGG
# GGA
# GAT
# ATA
# TAT
# ATC
# TCG
# CGT
# GTG
# TGT
# GTA
# TAA
# AAC
# ACA
# CAA
# AAA
# AAC
# ACG
# CGC
# GCT
# CTG
# TGA
# GAG
# AGT
# GTT
# TTT
# TTG
# TGT
# GTT
# TTC
# TCG
# CGC
# GCC
# CCA
# CAC
# ACA
# CAT
# ATA
# TAC
# ACT
# CTT
# TTA
# TAA
# AAT
# ATC
# TCC
# CCA
# CAC
# ACT
# CTG
# TGA
# GAG
# AGG
# GGT
# GTA
# TAA
# AAA
# AAC
# ACT
# CTA
# TAA
# AAC
# ACT
# CTC
# TCA
# CAG
# AGC
# GCG
# CGT
# GTA
# TAT
# ATG
# TGT
# GTG
# TGA
# GAT
# ATA
# TAG
# AGG
# GGT
# GTC
# TCT
# CTT
# TTA
# TAC
# ACA
# CAA
# AAA
# AAC
# ACT
# CTT
# TTC
# TCT
# CTT
# TTA
# TAT
# ATT
# TTT
# TTA
# TAG
# AGG
# GGT
# GTT
# TTT
# TTG
# TGT
# GTA
# TAG
# AGG
# GGT
# GTA
# TAA
# AAT
# ATT
# TTC
# TCG
# CGT
# GTC
# TCA
# CAA
# AAT
# ATA
# TAT
# ATT
# TTG
# TGC
# GCG
# CGG
# GGA
# GAA
# AAT
# ATA
# TAT
# ATC
# TCC
# CTT
# TTG
# TGA
# GAA
# AAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGA
# GAC
# ACT
# CTT
# TTA
# TAG
# AGA
# GAA
# AAT
# ATT
# TTA
# TAG
# AGT
# GTT
# TTG
# TGA
# GAA
# AAA
# AAG
# AGA
# GAA
# AAT
# ATT
# TTG
# TGT
# GTT
# TTT
# TTC
# TCA
# CAT
# ATT
# TTA
# TAG
# AGT
# GTA
# TAT
# ATT
# TTT
# TTC
# TCC
# CCT
# CTC
# TCA
# CAG
# AGT
# GTT
# TTT
# TTG
# TGA
# GAT
# ATT
# TTA
# TAA
# AAA
# AAT
# ATA
# TAG
# AGA
# GAT
# ATA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAC
# ACA
# CAA
# AAA
# AAT
# ATG
# TGG
# GGC
# GCA
# CAA
# AAT
# ATC
# TCC
# CCG
# CGC
# GCC
# CCT
# CTA
# TAG
# AGT
# GTT
# TTA
# TAC
# ACA
# CAT
# ATA
# TAC
# ACT
# CTA
# TAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCT
# CTG
# TGT
# GTA
# TAA
# AAG
# AGT
# GTA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAT
# ATC
# TCC
# CCG
# CGT
# GTT
# TTA
# TAC
# ACA
# CAA
# AAT
# ATA
# TAT
# ATC
# TCT
# CTG
# TGG
# GGA
# GAT
# ATA
# TAA
# AAC
# ACG
# CGT
# GTT
# TTC
# TCA
# CAT
# ATC
# TCA
# CAA
# AAT
# ATT
# TTA
# TAA
# AAT
# ATG
# TGA
# GAT
# ATT
# TTT
# TTC
# TCC
# CCT
# CTA
# TAT
# ATA
# TAT
# ATG
# TGC
# GCA
# CAA
# AAA
# AAC
# ACT
# CTC
# TCA
# CAC
# ACG
# CGT
# GTA
# TAC
# ACC
# CCT
# CTC
# TCT
# CTA
# TAC
# ACT
# CTT
# TTC
# TCT
# CTA
# TAA
# ATC
# TCA
# CAA
# AAC
# ACT
# CTA
# TAC
# ACT
# CTC
# TCT
# CTA
# TAT
# ATT
# TTA
# TAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAG
# AGT
# GTT
# TTA
# TAT
# ATA
# TAT
# ATC
# TCT
# CTG
# TGT
# GTT
# TTT
# TTT
# TTC
# TCC
# CCA
# CAT
# ATT
# TTC
# TCA
# CAT
# ATA
# TAA
# AAC
# ACC
# CCT
# CTA
# TAG
# AGA
# GAT
# ATA
# TAG
# AGT
# GTT
# TTA
# TAG
# AGT
# GTT
# TTT
# TTC
# TCA
# CAT
# ATT
# TTA
# TAC
# ACT
# CTC
# TCA
# CAT
# ATT
# TTA
# TAT
# ATA
# TAA
# AAA
# AAC
# ACT
# CTC
# TCC
# CCT
# CTT
# TTT
# TTG
# TGA
# GAT
# ATC
# TCA
# CAA
# AAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAA
# AAA
# AAT
# ATA
# TAA
# AAT
# ATC
# TCT
# CTG
# TGG
# GGA
# GAG
# AGT
# GTA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTT
# TTC
# TCT
# CTT
# TTT
# TTG
# TGT
# GTA
# TAA
# AAT
# ATA
# TAC
# ACG
# CGA
# GAT
# ATA
# TAA
# AAC
# ACC
# CCA
# CAA
# AAC
# ACT
# CTG
# TGA
# GAC
# ACC
# CCA
# CAT
# ATA
# TAA
# AAA
# AAT
# ATC
# TCT
# CTA
# TAC
# ACA
# CAC
# ACG
# CGG
# GGA
# GAC
# ACG
# CGA
# GAA
# AAA
# AAC
# ACC
# CCT
# CTT
# TTT
# TTT
# TTC
# TCC
# CCA
# CAT
# ATC
# TCA
# CAT
# ATG
# TGT
# GTT
# TTG
# TGA
# GAC
# ACC
# CCG
# CGT
# GTA
# TAT
# ATA
# TAC
# ACA
# CAC
# CTC
# TCA
# CAG
# AGT
# GTA
# TAA
# AAA
# AAT
# ATT
# TTT
# TTG
# TGG
# GGT
# GTG
# TGC
# GCC
# CCG
# CGC
# GCC
# CCA
# CAC
# ACT
# CTC
# TCC
# CCG
# CGA
# GAA
# AAT
# ATC
# TCG
# CGA
# GAA
# AAC
# ACG
# CGG
# GGA
# GAG
# AGG
# GGA
# GAC
# ACC
# CCT
# CTA
# TAC
# ACG
# CGC
# GCA
# CAT
# ATT
# TTA
# TAC
# ACA
# CAA
# AAG
# AGT
# GTG
# TGC
# GCG
# CGT
# GTT
# TTG
# TGC
# GCT
# CTC
# TCT
# CTA
# TAC
# ACC
# CCT
# CTA
# TAG
# AGC
# GCT
# CTG
# TGA
# GAG
# AGC
# GCT
# CTA
# TAT
# ATA
# TAG
# AGC
# GCG
# CGG
# GGC
# GCG
# CGT
# GTA
# TAA
# AAT
# ATC
# TCT
# CTT
# TTC
# TCT
# CTA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATA
# TAG
# AGT
# GTG
# TGT
# GTA
# TAT
# ATA
# TAT
# ATG
# TGA
# GAA
# AAA
# AAG
# AGT
# GTA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAT
# ATT
# TTA
# TAT
# ATA
# TAA
# AAT
# ATA
# TAA
# AAA
# AAT
# ATA
# TAA
# AAA
# AAG
# AGT
# GTT
# TTA
# TAT
# ATA
# TAT
# ATT
# TTC
# TCA
# CAA
# AAA
# AAC
# ACC
# CCT
# CTA
# TAT
# ATT
# TTT
# TTA
# TAA
# AAA
# AAA
# AAG
# AGG
# GGT
# GTA
# TAT
# ATA
# TAT
# ATT
# TTA
# TAC
# ACA
# CAA
# AAA
# AAT
# ATG
# TGT
# GTG
# TGA
# GAT
# ATA
# TAT
# ATT
# TTA
# TAC
# ACT
# CTA
# TAA
# AAA
# AAA
# AAG
# CAG
# AGT
# GTC
# TCA
# CAT
# ATT
# TTT
# TTG
# TGC
# GCT
# CTC
# TCT
# CTA
# TAC
# ACC
# CCG
# CGA
# GAC
# ACT
# CTG
# TGA
# GAG
# AGC
# GCT
# CTA
# TAT
# ATC
# TCA
# CAC
# ACG
# CGG
# GGA
# GAA
# AAG
# AGA
# GAA
# AAT
# ATT
# TTA
# TAT
# ATG
# TGG
# GGC
# GCG
# CGA
# GAT
# ATT
# TTT
# TTT
# TTA
# TAT
# ATA
# TAT
# ATT
# TTA
# TAG
# AGA
# GAG
# AGA
# GAT
# ATG
# TGA
# GAG
# AGT
# GTT
# TTA
# TAC
# ACT
# CTG
# TGA
# GAC
# ACA
# CAA
# AAC
# ACC
# CCT
# CTA
# TAA
# AAT
# ATA
# TAT
# ATA
# TAG
# AGA
# GAT
# ATA
# TAT
# ATG
# TGT
# GTA
# TAA
# AAT
# ATA
# TAA
# AAC
# ACT
# CTA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTA
# TAC
# ACA
# CAA
# AAT
# ATC
# TCT
# CTG
# TGA
# GAG
# AGT
# GTA
# TAT
# ATT
# TTA
# TAT
# ATT
# TTT
# TTA
# TAT
# ATT
# TTT
# TTC
# TCT
# CTT
# TTG
# TGT
# GTT
# TTA
# TAT
# ATG
# TGA
# GAC
# ACA
# CAT
# ATT
# TTA
# TAT
# ATG
# TGT
# GTA
# TAA
# AAA
# AAT
# ATA
# TAA
# AAC
# ACG
# CGT
# GTG
# TGT
# GTA
# TAG
# AGT
# GTT
# TTA
# TAA
# AAT
# ATC
# TCT
# CTT
# TTA
# TAT
# ATT
# TTA
# TAG
# AGA
# GAA
# AAA
# AAC
# ACT
# CTA
# TAT
# ATC
# TCA
# CAA
# AAA
# AAG
# AGT
# GTT
# TTA
# TAC
# ACT
# CTA
# TAA
# AAT
# ATT
# TTC
# TCT
# CTA
# TAA
# AAC
# GTA
# TAG
# AGA
# GAT
# ATC
# TCA
# CAC
# ACC
# CCT
# CTA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAT
# ATA
# TAA
# AAT
# ATT
# TTT
# TTC
# TCA
# CAT
# ATT
# TTA
# TAA
# AAA
# AAT
# ATC
# TCC
# CCA
# CAA
# AAC
# ACC
# CCA
# CAA
# AAG
# AGG
# GGG
# GGT
# GTA
# TAA
# AAC
# ACT
# CTC
# TCT
# CTT
# TTC
# TCG
# CGC
# GCC
# CCT
# CTA
# TAT
# ATA
# TAT
# ATC
# TCT
# CTG
# TGG
# GGC
# GCG
# CGA
# GAT
# ATA
# TAA
# AAT
# ATA
# TAG
# AGT
# GTA
# TAA
# AAT
# ATT
# TTC
# TCA
# CAA
# AAA
# AAC
# ACA
# CAT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGT
# GTG
# TGC
# GCT
# CTC
# TCT
# CTC
# TCA
# CAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAT
# ATC
# TCA
# CAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAT
# ATT
# TTC
# TCA
# CAT
# ATA
# TAA
# AAG
# AGA
# GAT
# ATA
# TAA
# AAC
# ACC
# CCC
# CCA
# CAT
# ATG
# TGG
# GGC
# GCA
# CAA
# AAC
# ACA
# CAT
# ATA
# TAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGT
# GTA
# TAG
# AGC
# GCC
# CCG
# CGA
# GAA
# AAG
# AGC
# GCT
# CTA
# TAC
# ACT
# CTC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGA
# GAA
# AAT
# ATA
# TAT
# ATG
# TGG
# GGC
# GCT
# CTC
# TCC
# CCG
# CGT
# GTG
# TGA
# GAC
# ACC
# CCT
# CTG
# TGG
# GGA
# GAC
# ACT
# CTC
# TCG
# CGA
# GAA
# AAC
# ACC
# CCA
# CAG
# AGG
# GGG
# GGA
# GAC
# GGC
# GCG
# CGC
# GCG
# CGC
# GCC
# CCC
# CCA
# CAA
# AAG
# AGG
# GGG
# GGG
# GGA
# GAC
# ACT
# CTC
# TCG
# CGA
# GAA
# AAC
# ACC
# CCC
# CCC
# CCT
# CTG
# TGA
# GAC
# ACC
# CCA
# CAC
# ACC
# CCC
# CCG
# CGC
# GCG
# CGT
# GTG
# TGA
# GAC
# ACA
# CAG
# AGG
# GGC
# GCG
# CGG
# GGG
# GGT
# GTA
# TAT
# ATT
# TTC
# TCT
# CTA
# TAA
# AAC
# ACC
# CCA
# CAA
# AAC
# ACT
# CTG
# TGA
# GAA
# AAC
# ACT
# CTA
# TAT
# ATG
# TGA
# GAG
# AGC
# GCG
# CGC
# GCA
# CAA
# AAA
# AAC
# ACG
# CGT
# GTA
# TAT
# ATG
# TGG
# GGA
# GAC
# ACA
# CAT
# ATG
# TGA
# GAC
# ACT
# CTT
# TTC
# TCC
# CCT
# CTA
# TAC
# ACA
# CAT
# ATA
# TAG
# AGT
# GTA
# TAT
# ATT
# TTA
# TAC
# ACA
# CAT
# ATA
# TAA
# AAC
# ACC
# CCA
# CAG
# AGT
# GTA
# TAA
# AAT
# ATA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAT
# ATT
# TTA
# TAC
# ACG
# CGG
# GGG
# GGC
# GCG
# CGA
# GAT
# ATC
# TCA
# CAG
# AGT
# GTC
# TCC
# CCA
# CAG
# AGT
# GTG
# TGC
# GCT
# CTT
# TTG
# TGA
# GAA
# AAA
# AAT
# ATA
# TAG
# AGT
# GTT
# TTA
# TAC
# ACC
# CCA
# CAT
# ATC
# TCC
# CCT
# CTT
# TTG
# TGG
# GGG
# GGA
# GAC
# ACG
# CGA
# GAT
# ATC
# TCG
# CGT
# GTA
# TAC
# ACT
# CTT
# TTA
# TAG
# AGC
# GCA
# CAA
# AAG
# AGA
# GAA
# AAT
# ATA
# TAT
# ATT
# TTT
# TTT
# TTT
# TGG
# GGT
# GTG
# TGC
# GCC
# CCC
# CCG
# CGA
# GAA
# AAG
# AGT
# GTC
# TCG
# CGG
# GGA
# GAT
# ATT
# TTC
# TCG
# CGA
# GAA
# AAC
# ACC
# CCG
# CGA
# GAC
# ACA
# CAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGT
# GTA
# TAG
# AGC
# GCC
# CCG
# CGG
# GGA
# GAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAG
# AGT
# GTC
# TCT
# CTT
# TTC
# TCT
# CTG
# TGT
# GTG
# TGT
# GTT
# TTT
# TTA
# TAC
# ACC
# CCA
# CAA
# AAT
# ATT
# TTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAT
# ATT
# TTC
# TCG
# CGG
# GGG
# GGC
# GCA
# CAT
# ATT
# TTG
# TGT
# GTG
# TGC
# GCT
# CTT
# TTC
# TCA
# CAA
# AAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAA
# AAC
# ACA
# CAT
# ATG
# TGT
# GTA
# TAA
# AAT
# ATG
# TGC
# GCT
# CTA
# TAG
# AGG
# GGT
# GTA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAT
# ATT
# TTA
# TAC
# ACA
# CAA
# AAC
# ACT
# CTT
# TTA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAA
# AAT
# ATT
# TTC
# TCA
# CAA
# AAC
# ACG
# CGT
# GTG
# TGG
# GGC
# GCC
# CCA
# CAT
# ATT
# TTG
# TGT
# GTA
# TAA
# AAA
# AAG
# AGA
# GAA
# AAG
# AGT
# GTT
# TTA
# TAT
# ATC
# TCT
# CTT
# TTA
# TAT
# ATT
# TTA
# TAC
# ACC
# CCA
# CAT
# ATT
# TTA
# TAA
# AAT
# ATG
# TGT
# GTA
# TAG
# AGA
# GAC
# ACA
# CAT
# ATC
# TCG
# CGG
# GGT
# GTC
# TCA
# CAC
# TTA
# TAC
# ACA
# CAT
# ATT
# TTA
# TAG
# AGC
# GCT
# CTG
# TGC
# GCA
# CAA
# AAT
# ATT
# TTT
# TTT
# TTA
# TAT
# ATC
# TCA
# CAA
# AAA
# AAT
# ATT
# TTC
# TCT
# CTT
# TTT
# TTT
# TTT
# TTG
# TGG
# GGG
# GGC
# GCA
# CAT
# ATA
# TAG
# AGA
# GAT
# ATT
# TTA
# TAG
# AGC
# GCC
# CCC
# CCT
# CTG
# TGG
# GGT
# GTA
# TAA
# AAA
# AAA
# AAG
# AGT
# GTT
# TTC
# TCA
# CAT
# ATT
# TTT
# TTT
# TTT
# TTG
# TGA
# GAT
# ATC
# TCA
# CAT
# ATT
# TTT
# TTT
# TTA
# TAT
# ATA
# TAA
# AAT
# ATT
# TTA
# TAC
# ACT
# CTC
# TCT
# CTA
# TAT
# ATG
# TGT
# GTT
# TTG
# TGT
# GTT
# TTT
# TTA
# TAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAT
# ATA
# TAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAC
# ACG
# CGT
# GTA
# TAA
# AAA
# AAA
# AAA
# AAC
# ACA
# CAA
# AAA
# AAA
# AAT
# ATA
# TAT
# ATA
# TAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTC
# TCC
# CCC
# CCC
# CCG
# CGA
# GAA
# AAG
# AGG
# GGG
# GGA
# GAG
# AGG
# GGC
# GCG
# CGA
# GAT
# ATA
# TAT
# ATA
# TAT
# ATC
# TCG
# CGT
# GTC
# TCA
# CAT
# ATT
# TTA
# TAA
# AAT
# ATG
# TGC
# GCC
# CCC
# CCA
# CAG
# AGC
# GCA
# CAA
# AAA
# AAG
# AGA
# GAG
# AGT
# GTT
# TTT
# TTT
# TTA
# TAC
# ACT
# CTC
# TCT
# CTC
# TCT
# CTG
# TGG
# GGG
# GGA
# GAG
# CGG
# GGT
# GTA
# TAG
# AGA
# GAT
# ATG
# TGA
# GAT
# ATA
# TAA
# AAT
# ATC
# TCA
# CAC
# ACT
# CTC
# TCT
# CTT
# TTA
# TAG
# AGC
# GCA
# CAA
# AAC
# ACA
# CAT
# ATT
# TTG
# TGA
# GAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTT
# TTC
# TCT
# CTT
# TTT
# TTG
# TGG
# GGT
# GTA
# TAG
# AGT
# GTT
# TTG
# TGA
# GAG
# AGA
# GAT
# ATT
# TTT
# TTA
# TAG
# AGT
# GTA
# TAG
# AGA
# GAC
# ACA
# CAT
# ATA
# TAT
# ATC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCC
# CCT
# CTT
# TTT
# TTA
# TAC
# ACA
# CAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAA
# AAA
# AAA
# AAT
# ATA
# TAT
# ATT
# TTT
# TTC
# TCT
# CTT
# TTA
# TAC
# ACA
# CAA
# AAT
# ATA
# TAA
# AAA
# AAT
# ATA
# TAA
# AAT
# ATA
# TAG
# AGA
# GAG
# AGG
# GGT
# GTT
# TTA
# TAG
# AGT
# GTA
# TAT
# ATA
# TAA
# AAA
# AAT
# ATT
# TTG
# TGG
# GGG
# GGA
# GAA
# AAT
# ATA
# TAA
# AAC
# ACA
# CAC
# ACC
# CCC
# CCT
# CTC
# TCC
# CCC
# CCA
# CAA
# AAT
# ATT
# TTA
# TAA
# AAG
# AGG
# GGG
# GGA
# GAG
# AGG
# GGG
# GGT
# GTG
# TGT
# GTA
# TAT
# ATA
# TAC
# ACA
# CAC
# ACT
# CTT
# TTA
# TAA
# AAA
# AAG
# AGA
# GAG
# AGT
# GTG
# TGC
# GCA
# CAC
# ACG
# CGA
# GAA
# AAC
# ACC
# CCG
# CGC
# GCC
# CCT
# CTG
# TGC
# GCA
# CAC
# ACA
# CAC
# ACC
# CCC
# CCA
# CAA
# AAC
# ACT
# AGG
# GGT
# GTG
# TGA
# GAG
# AGT
# GTA
# TAT
# ATG
# TGC
# GCT
# CTT
# TTC
# TCT
# CTT
# TTC
# TCA
# CAG
# AGT
# GTA
# TAC
# ACC
# CCG
# CGT
# GTC
# TCT
# CTA
# TAG
# AGT
# GTT
# TTT
# TTA
# TAA
# AAT
# ATG
# TGA
# GAT
# ATA
# TAG
# AGT
# GTT
# TTT
# TTT
# TTT
# TTA
# TAA
# AAC
# ACA
# CAT
# ATT
# TTG
# TGT
# GTT
# TTA
# TAA
# AAT
# ATT
# TTT
# TTC
# TCC
# CCA
# CAA
# AAT
# ATT
# TTG
# TGT
# GTG
# TGA
# GAG
# AGT
# GTC
# TCG
# CGT
# GTA
# TAA
# AAG
# AGT
# GTT
# TTC
# TCA
# CAT
# ATG
# TGT
# GTG
# TGA
# GAA
# AAA
# AAA
# AAA
# AAG
# AGT
# GTA
# TAT
# ATT
# TTC
# TCA
# CAA
# AAC
# ACA
# CAT
# ATA
# TAT
# ATC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGA
# GAT
# ATC
# TCA
# CAA
# AAC
# ACT
# CTA
# TAA
# AAG
# AGT
# GTA
# TAT
# ATT
# TTT
# TTT
# TTT
# TTA
# TAC
# ACG
# CGA
# GAC
# ACC
# CCC
# CCA
# CAT
# ATT
# TTT
# TTT
# TTA
# TAA
# AAA
# AAT
# ATG
# TGA
# GAA
# AAT
# ATT
# TTT
# TTA
# TAG
# AGT
# GTT
# TTG
# TGA
# GAT
# ATC
# TCT
# CTA
# TAT
# ATT
# TTG
# TGT
# GTA
# TAA
# AAA
# AAA
# AAG
# AGC
# GCA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAT
# ATG
# TGG
# GGT
# GTA
# TAC
# ACA
# CAT
# ATT
# TTG
# TGG
# GGA
# GAT
# ATA
# TAT
# ATC
# TCT
# CTT
# TTT
# TTA
# TAT
# ATC
# TCT
# CTT
# TTA

# %%
# Out:
# LUZ7 t5 plus
