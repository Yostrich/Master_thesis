# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x18\x08\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c2TSS_LUZ7_t10/TSS_seq_LUZ7_enriched_t10.plus.fa.out\x94\x8c\'TSS_LUZ7_t10/random_seq_LUZ7_t10.fa.out\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x11\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x17)}\x94\x8c\x05_name\x94h\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c>TSS_LUZ7_t10/structural_properties/LUZ7_t10_curvature.plus.csv\x94\x8c>TSS_LUZ7_t10/structural_properties/LUZ7_t10_stability.plus.csv\x94\x8c@TSS_LUZ7_t10/structural_properties/LUZ7_t10_bendability.plus.csv\x94\x8cITSS_LUZ7_t10/structural_properties/random_seq_LUZ7_t10_curvature.plus.csv\x94\x8cITSS_LUZ7_t10/structural_properties/random_seq_LUZ7_t10_stability.plus.csv\x94\x8cKTSS_LUZ7_t10/structural_properties/random_seq_LUZ7_t10_bendability.plus.csv\x94e}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x04LUZ7\x94\x8c\x03t10\x94\x8c\x04plus\x94e}\x94(h\r}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94b\x8c\x05phage\x94hI\x8c\x05ident\x94hJ\x8c\x04sign\x94hKub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bhhK\x01hjK\x01hlheub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c"logs/notebooks/LUZ7_t10.plus.ipynb\x94a}\x94(h\r}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bh~h{ub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\nLUZ7.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0]
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0,0]
def getCurvature(seq):
    return CurvedDNA(seq, 'nucleosome').curvature[0,:].tolist()
def savePropertiesToCsv(propertyfunc, fastaFile, window,outCSV,bp_upstream,bp_downstream):
    fasta_sequences = SeqIO.parse(open(fastaFile),'fasta')
    df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
    for fasta in fasta_sequences:
        nameSeq, sequence = fasta.id, str(fasta.seq)
        df[str(nameSeq)] = propertyfunc(sequence)
        df[str(nameSeq)] = df[str(nameSeq)].rolling(window).mean()
    df["mean"] = df.mean(axis=1)
    df.to_csv(outCSV, index=True)

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
partial_stability = lambda y: seqTodiValues(y, "stability")
partial_bendability = lambda y: seqTotriValues(y, "DNAse1_bendability")
savePropertiesToCsv(getCurvature,snakemake.input[0], 20, snakemake.output[0],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[0], 20, snakemake.output[1],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[0], 20, snakemake.output[2],bp_upstream,bp_downstream)
savePropertiesToCsv(getCurvature,snakemake.input[1], 20, snakemake.output[3],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[1], 20, snakemake.output[4],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[1], 20, snakemake.output[5],bp_upstream,bp_downstream)
# Out:
# CAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATC
# TCT
# CTA
# TAC
# ACT
# CTA
# TAC
# ACA
# CAA
# AAC
# ACC
# CCA
# CAG
# AGC
# GCT
# CTG
# TGC
# GCT
# CTG
# TGC
# GCG
# CGT
# GTC
# TCT
# CTG
# TGC
# GCT
# CTG
# TGG
# GGA
# GAA
# AAC
# ACG
# CGG
# GGG
# GGA
# GAT
# ATG
# TGC
# GCT
# CTG
# TGC
# GCC
# CCA
# CAT
# ATA
# TAC
# ACG
# CGG
# GGG
# GGG
# GGT
# GTG
# TGA
# GAT
# ATT
# TTC
# TCC
# CCA
# CAT
# ATT
# TTC
# TCT
# CTC
# TCT
# CTG
# TGC
# GCG
# CGT
# GTG
# TGC
# GCG
# CGC
# GCG
# CGT
# GTC
# TCC
# CCG
# CGC
# GCG
# CGC
# GCA
# CAC
# ACG
# CGG
# GGT
# GTT
# TTG
# TGT
# GTT
# TTG
# TGG
# GGT
# GTG
# TGG
# GGT
# GTT
# TTC
# TCC
# CCG
# CGA
# GAA
# AAC
# ACG
# CGT
# GTC
# TCA
# CAA
# AAG
# AGA
# GAG
# AGC
# GCA
# CAA
# AAC
# ACC
# CCT
# CTC
# TCC
# CCG
# CGG
# GGG
# GGC
# GCT
# CTT
# TTC
# TCG
# CGG
# GGA
# GAG
# AGG
# GGT
# GTA
# TAG
# AGT
# GTT
# TTC
# TCC
# CCT
# CTC
# TCG
# CGG
# GGG
# GGC
# GCC
# CCT
# CTC
# TCA
# CAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCT
# CTT
# TTC
# TCC
# CCG
# CGG
# GGA
# GAG
# AGT
# GTA
# TAC
# ACG
# CGA
# GAG
# AGG
# GGC
# GCA
# CAC
# ACT
# CTG
# TGC
# GCT
# CTA
# TAA
# AAA
# AAC
# ACC
# CCA
# CAG
# AGT
# GTG
# TGG
# GGG
# GGA
# TGA
# GAC
# ACA
# CAC
# ACT
# CTA
# TAC
# ACC
# CCC
# CCC
# CCG
# CGT
# GTC
# TCT
# CTC
# TCA
# CAG
# AGG
# GGG
# GGT
# GTA
# TAG
# AGG
# GGG
# GGG
# GGG
# GGT
# GTT
# TTG
# TGG
# GGG
# GGG
# GGA
# GAG
# AGG
# GGG
# GGT
# GTT
# TTA
# TAG
# AGA
# GAG
# AGG
# GGT
# GTG
# TGA
# GAA
# AAT
# ATC
# TCC
# CCC
# CCT
# CTC
# TCC
# CCC
# CCC
# CCA
# CAG
# AGG
# GGG
# GGT
# GTC
# TCC
# CCA
# CAC
# ACC
# CCC
# CCG
# CGA
# GAC
# ACT
# CTC
# TCC
# CCC
# CCG
# CGG
# GGC
# GCC
# CCC
# CCC
# CCC
# CCT
# CTC
# TCC
# CCG
# CGG
# GGG
# GGG
# GGG
# GGC
# GCT
# CTT
# TTG
# TGA
# GAA
# AAT
# ATG
# TGT
# GTG
# TGA
# GAA
# AAT
# ATT
# TTC
# TCA
# CAA
# AAG
# AGA
# GAG
# AGG
# GGG
# GGG
# GGG
# GGA
# GAG
# AGG
# GGG
# GGT
# GTG
# TGG
# GGA
# GAC
# ACC
# CCC
# CCC
# CCT
# CTT
# TTT
# TTA
# TAT
# ATA
# TAT
# ATA
# TAT
# ATA
# TAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGT
# GTG
# TGA
# GAT
# ATC
# TCA
# CAT
# ATT
# TTT
# TTT
# TTT
# TTT
# TTA
# TAA
# AAC
# ACC
# CCA
# CAG
# AGA
# GAG
# AGG
# GGT
# GTT
# TTC
# TCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAT
# ATG
# TGA
# GAA
# AAA
# AAA
# AAA
# AAG
# AGC
# GCT
# CTG
# TGA
# GAC
# ACC
# CCG
# CGC
# GCA
# CAG
# AGC
# GCA
# CAG
# AGA
# AGA
# GAC
# ACA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGG
# GGA
# GAT
# ATG
# TGA
# GAA
# AAA
# AAC
# ACC
# CCG
# CGA
# GAA
# AAC
# ACT
# CTA
# TAC
# ACT
# CTG
# TGA
# GAC
# ACG
# CGA
# GAC
# ACC
# CCG
# CGT
# GTT
# TTC
# TCT
# CTC
# TCA
# CAT
# ATC
# TCA
# CAC
# ACG
# CGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGC
# GCT
# CTC
# TCG
# CGG
# GGG
# GGG
# GGT
# GTT
# TTT
# TTG
# TGA
# GAA
# AAG
# AGA
# GAT
# ATA
# TAG
# AGG
# GGG
# GGC
# GCC
# CCG
# CGC
# GCT
# CTT
# TTC
# TCC
# CCA
# CAG
# AGC
# GCG
# CGG
# GGC
# GCT
# CTC
# TCT
# CTT
# TTT
# TTC
# TCG
# CGA
# GAT
# ATT
# TTA
# TAA
# AAC
# ACT
# CTA
# TAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGT
# GTG
# TGT
# GTC
# TCT
# CTA
# TAT
# ATG
# TGG
# GGC
# GCT
# CTC
# TCA
# CAA
# AAG
# AGT
# GTC
# TCA
# CAA
# AAT
# ATG
# TGA
# GAC
# ACA
# CAA
# AAC
# ACT
# CTT
# TTG
# TGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGA
# GAT
# ATC
# TCT
# CTC
# TCT
# CTG
# TGG
# GGC
# GCG
# CGA
# GAA
# AAT
# ATC
# TCC
# CCG
# CGC
# GCT
# CTA
# TAC
# ACC
# CCG
# CGG
# GGT
# GTA
# TAA
# AAG
# AGT
# GTC
# TCG
# CGC
# GCT
# CTG
# TGA
# GAG
# AGT
# GTC
# TCT
# CTC
# TCA
# CAA
# AAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTG
# TGG
# GGA
# GAG
# AGA
# CGC
# GCT
# CTC
# TCT
# CTA
# TAC
# ACC
# CCT
# CTT
# TTA
# TAG
# AGA
# GAG
# AGG
# GGT
# GTC
# TCT
# CTG
# TGA
# GAG
# AGT
# GTA
# TAG
# AGA
# GAC
# ACG
# CGG
# GGA
# GAC
# ACG
# CGT
# GTA
# TAG
# AGG
# GGC
# GCC
# CCT
# CTG
# TGG
# GGG
# GGG
# GGT
# GTG
# TGC
# GCC
# CCC
# CCT
# CTT
# TTG
# TGT
# GTT
# TTG
# TGT
# GTT
# TTC
# TCT
# CTG
# TGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGG
# GGT
# GTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAA
# AAC
# ACC
# CCT
# CTC
# TCC
# CCG
# CGG
# GGT
# GTT
# TTG
# TGT
# GTT
# TTC
# TCA
# CAT
# ATT
# TTT
# TTC
# TCG
# CGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATG
# TGA
# GAA
# AAA
# AAC
# ACC
# CCT
# CTG
# TGC
# GCC
# CCT
# CTG
# TGC
# GCT
# CTG
# TGG
# GGC
# GCC
# CCT
# CTG
# TGA
# GAG
# AGA
# GAT
# ATC
# TCT
# CTC
# TCG
# CGA
# GAT
# ATA
# TAC
# ACC
# CCC
# CCA
# CAC
# ACA
# CAC
# ACT
# CTC
# TCA
# CAT
# ATG
# TGG
# GGG
# GGT
# GTC
# TCT
# CTC
# TCC
# CCA
# CAC
# ACT
# CTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAC
# ACC
# CCA
# CAA
# AAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TCA
# CAT
# ATC
# TCC
# CCA
# CAC
# ACG
# CGT
# GTT
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# ...
# TCT
# CTT
# TTC
# TCT
# CTG
# TGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACC
# CCA
# CAT
# ATC
# TCA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCA
# CAC
# ACC
# CCG
# CGT
# GTA
# TAC
# ACA
# CAC
# ACA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCA
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# CAC
# ACA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACA
# CAA
# TTG
# TGG
# GGC
# GCC
# CCG
# CGA
# GAC
# ACT
# CTG
# TGA
# GAG
# AGC
# GCC
# CCA
# CAT
# ATG
# TGA
# GAT
# ATG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCA
# CAT
# ATC
# TCC
# CCC
# CCC
# CCC
# CCG
# CGA
# GAG
# AGA
# GAG
# AGA
# GAT
# ATG
# TGG
# GGC
# GCA
# CAC
# ACC
# CCG
# CGA
# GAC
# ACG
# CGA
# GAT
# ATC
# TCT
# CTT
# TTC
# TCT
# CTG
# TGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACC
# CCA
# CAT
# ATC
# TCA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCA
# CAC
# ACC
# CCG
# CGT
# GTA
# TAC
# ACA
# CAC
# ACA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCA
# CAC
# ACA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACA
# CAA
# AAC
# ACG
# CGT
# GTA
# TAG
# AGG
# GGG
# GGG
# GGA
# GAT
# ATC
# TCT
# CTT
# TTA
# TAC
# ACC
# CCA
# CAT
# ATC
# TCC
# CCG
# CGG
# GGG
# GGA
# GAA
# AAC
# ACG
# CGG
# GGG
# GGT
# GTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCC
# CCA
# CAG
# AGA
# GAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTG
# TGA
# GAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAA
# AAG
# AGT
# GTT
# TTG
# TGC
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# CAT
# ATT
# TTC
# TCA
# CAG
# AGA
# GAA
# AAC
# ACG
# CGT
# GTG
# TGA
# GAG
# AGT
# GTC
# TCG
# CGG
# GGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGT
# GTG
# TGT
# GTC
# TCT
# CTG
# TGT
# GTT
# TTC
# TCC
# CCA
# CAG
# AGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGG
# GGT
# GTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCT
# CTT
# TTC
# TCG
# CGA
# GAC
# ACT
# CTT
# TTG
# TGT
# GTT
# TTG
# TGT
# GTA
# TAC
# ACG
# CGC
# GCA
# CAC
# ACT
# CTG
# TGA
# GAC
# ACG
# CGT
# GTA
# TAG
# AGC
# GCT
# CTG
# TGG
# GGC
# GCG
# CGA
# GAT
# ATG
# TGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGC
# GCA
# CAT
# ATA
# TAG
# AGT
# GTT
# TTC
# TCT
# CTG
# TGC
# GCA
# CAT
# ATC
# TCG
# CGT
# GTC
# TCC
# CCA
# CAC
# ACC
# CCG
# CGC
# GCT
# CTG
# TGA
# GAA
# AAT
# ATC
# TCT
# CTT
# TTG
# TGT
# GTC
# TCG
# CGG
# GGG
# GGG
# GGA
# GAA
# AAG
# AGG
# GGT
# GTT
# TTC
# TCG
# CGG
# GGC
# GCT
# CTG
# TGA
# GAA
# AAT
# ATG
# TGC
# GCA
# CAT
# ATC
# TCG
# CGA
# GAT
# ATA
# TAT
# ATT
# TTG
# TGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGC
# GCC
# CCC
# CCA
# CAT
# ATC
# TCA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGT
# GTG
# TGG
# GGC
# GCT
# CTG
# TGA
# GAC
# ACG
# CGT
# GTA
# TAC
# ACT
# CTT
# TTC
# TCA
# CAC
# ACC
# ACT
# CTG
# TGA
# GAG
# AGT
# GTG
# TGA
# GAT
# ATC
# TCG
# CGG
# GGC
# GCT
# CTG
# TGT
# GTG
# TGC
# GCA
# CAG
# AGG
# GGT
# GTA
# TAC
# ACA
# CAG
# AGC
# GCA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGA
# GAG
# AGT
# GTC
# TCA
# CAT
# ATG
# TGA
# GAT
# ATA
# TAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGT
# GTT
# TTA
# TAT
# ATG
# TGT
# GTA
# TAT
# ATA
# TAG
# AGG
# GGT
# GTT
# TTG
# TGA
# GAA
# AAC
# ACC
# CCT
# CTA
# TAG
# AGC
# GCA
# CAT
# ATA
# TAA
# AAC
# ACA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TCA
# CAA
# AAA
# AAC
# ACC
# CCA
# CAA
# AAG
# AGG
# GGA
# GAG
# AGA
# GAT
# ATA
# TAC
# ACA
# CAC
# ACC
# CCT
# CTA
# TAT
# ATG
# TGG
# GGC
# GCA
# CAC
# ACT
# CTC
# TCG
# CGT
# GTC
# TCA
# CAA
# AAC
# ACC
# CCT
# CTG
# TGA
# GAC
# ACA
# CAA
# AAT
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# ATC
# TCC
# CCC
# CCA
# CAG
# AGA
# GAC
# ACG
# CGA
# GAA
# AAG
# AGA
# GAC
# ACC
# CCT
# CTG
# TGA
# GAT
# ATT
# TTG
# TGA
# GAG
# AGT
# GTT
# TTC
# TCG
# CGT
# GTT
# TTC
# TCA
# CAC
# ACT
# CTT
# TTC
# TCA
# CAG
# AGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGG
# GGA
# GAG
# AGA
# GAA
# AAA
# AAT
# ATA
# TAA
# AAA
# AAT
# ATA
# TAC
# ACT
# CTA
# TAT
# ATA
# TAA
# AAG
# AGG
# GGA
# GAG
# AGG
# GGG
# GGA
# GAT
# ATT
# GAT
# ATC
# TCT
# CTG
# TGA
# GAA
# AAG
# AGA
# GAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACT
# CTC
# TCT
# CTG
# TGT
# GTA
# TAC
# ACA
# CAT
# ATG
# TGA
# GAG
# AGG
# GGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTG
# TGG
# GGT
# GTT
# TTT
# TTC
# TCC
# CCG
# CGC
# GCC
# CCT
# CTC
# TCC
# CCT
# CTC
# TCT
# CTA
# TAC
# ACG
# CGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGC
# GCG
# CGC
# GCA
# CAT
# ATA
# TAA
# AAG
# AGC
# GCA
# CAC
# ACA
# CAG
# AGG
# GGA
# GAA
# AAG
# AGG
# GGA
# GAA
# AAC
# ACG
# CGT
# GTC
# TCG
# CGA
# GAG
# AGT
# GTT
# TTT
# TTA
# TAT
# ATG
# TGG
# GGA
# GAC
# ACG
# CGT
# GTG
# TGA
# GAT
# ATA
# TAA
# AAC
# ACT
# CTT
# TTT
# TTC
# TCA
# CAA
# AAC
# ACA
# CAG
# AGG
# GGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAT
# ATC
# TCA
# CAG
# AGA
# GAC
# ACA
# CAA
# AAG
# AGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAT
# ATG
# TGA
# GAT
# ATC
# TCA
# CAC
# ACC
# CCA
# CAA
# AAT
# ATA
# TAA
# AAT
# ATT
# TTT
# TTC
# TCT
# CTT
# TTC
# TCC
# CCA
# CAT
# ATG
# TGG
# GGA
# GAG
# AGA
# GAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAC
# ACC
# CCA
# CAA
# AAA
# AAC
# ACA
# CAG
# AGT
# GTT
# TTA
# TAG
# AGA
# GAC
# ACT
# CTG
# TGT
# GTT
# TTG
# TGA
# GAG
# AGG
# GGG
# GGA
# GAG
# AAG
# AGG
# GGG
# GGG
# GGA
# GAC
# ACT
# CTC
# TCA
# CAA
# AAT
# ATA
# TAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATA
# TAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTC
# TCT
# CTA
# TAA
# AAA
# AAC
# ACG
# CGA
# GAG
# AGC
# GCA
# CAC
# ACA
# CAT
# ATT
# TTC
# TCT
# CTC
# TCC
# CCT
# CTA
# TAT
# ATT
# TTG
# TGG
# GGC
# GCT
# CTT
# TTG
# TGT
# GTC
# TCG
# CGC
# GCT
# CTA
# TAC
# ACA
# CAT
# ATG
# TGT
# GTA
# TAC
# ACT
# CTC
# TCC
# CCA
# CAT
# ATC
# TCA
# CAA
# AAG
# AGC
# GCG
# CGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAT
# ATC
# TCG
# CGA
# GAA
# AAT
# ATA
# TAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCC
# CCC
# CCC
# CCA
# CAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATC
# TCT
# CTG
# TGA
# GAC
# ACA
# CAA
# AAC
# ACG
# CGT
# GTG
# TGG
# GGG
# GGT
# GTC
# TCT
# CTC
# TCT
# CTA
# TAT
# ATA
# TAA
# AAA
# AAG
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# AGG
# GGA
# GAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGT
# GTG
# TGG
# GGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACT
# CTA
# TAA
# AAT
# AGC
# GCG
# CGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAT
# ATC
# TCG
# CGA
# GAA
# AAT
# ATA
# TAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCC
# CCC
# CCC
# CCA
# CAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATC
# TCT
# CTG
# TGA
# GAC
# ACA
# CAA
# AAC
# ACG
# CGT
# GTG
# TGG
# GGG
# GGT
# GTC
# TCT
# CTC
# TCT
# CTA
# TAT
# ATA
# TAA
# AAA
# AAG
# AGG
# GGA
# GAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGT
# GTG
# TGG
# GGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACT
# CTA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAA
# AAG
# AGG
# GGT
# GTG
# TGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAT
# ATG
# TGA
# GAG
# AGA
# GAC
# ACC
# CCA
# CAG
# AGG
# GGA
# GAA
# AAT
# ATG
# TGA
# GAT
# ATA
# TAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGG
# GGT
# GTG
# TGT
# GTT
# TTT
# TTC
# TCG
# CGG
# GGC
# GCA
# CAC
# ACC
# CCT
# CTG
# TGT
# GTA
# TAT
# ATA
# TAA
# AAC
# ACA
# CAT
# ATC
# TCC
# CCG
# CGC
# GCT
# CTT
# TTG
# TGT
# GTA
# TAC
# ACT
# CTC
# TCT
# CTA
# TAA
# AAA
# AAT
# ATA
# TAC
# ACA
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# GGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACT
# CTA
# TAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAA
# AAG
# AGG
# GGT
# GTG
# TGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAT
# ATG
# TGA
# GAG
# AGA
# GAC
# ACC
# CCA
# CAG
# AGG
# GGA
# GAA
# AAT
# ATG
# TGA
# GAT
# ATA
# TAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGG
# GGT
# GTG
# TGT
# GTT
# TTT
# TTC
# TCG
# CGG
# GGC
# GCA
# CAC
# ACC
# CCT
# CTG
# TGT
# GTA
# TAT
# ATA
# TAA
# AAC
# ACA
# CAT
# ATC
# TCC
# CCG
# CGC
# GCT
# CTT
# TTG
# TGT
# GTA
# TAC
# ACT
# CTC
# TCT
# CTA
# TAA
# AAA
# AAT
# ATA
# TAC
# ACA
# CAA
# AAT
# ATA
# TAA
# AAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGT
# GTT
# TTG
# TGC
# GCC
# CCC
# CCT
# CTG
# TGG
# GGC
# GCA
# CAC
# ACT
# CTG
# TGG
# GGC
# GCC
# CCG
# CGT
# GTA
# TAT
# ATG
# TGT
# GTT
# TTC
# TCG
# CGA
# GAG
# AGA
# GAA
# AAA
# AAT
# ATT
# TTG
# TGA
# GAC
# ACT
# CTG
# TGC
# GCT
# CTG
# TGA
# GAC
# ACT
# CTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCT
# CTA
# TAT
# ATA
# TAA
# AAG
# AGC
# GCA
# CAG
# AGA
# GAC
# ACG
# CGG
# GGG
# GGG
# GGT
# GTG
# TGT
# GTA
# TAT
# ATC
# TCC
# CCT
# CTA
# TAC
# ACG
# CGA
# GAT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGG
# GGA
# GAA
# AAG
# AGC
# GGC
# GCA
# CAC
# ACG
# CGC
# GCA
# CAT
# ATA
# TAG
# AGG
# GGA
# GAC
# ACG
# CGT
# GTG
# TGT
# GTA
# TAG
# AGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAA
# AAC
# ACC
# CCA
# CAG
# AGA
# GAA
# AAA
# AAC
# ACG
# CGG
# GGA
# GAA
# AAG
# AGT
# GTT
# TTG
# TGA
# GAA
# AAA
# AAT
# ATT
# TTC
# TCG
# CGC
# GCA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATA
# TAC
# ACT
# CTT
# TTT
# TTT
# TTT
# TTA
# TAT
# ATC
# TCG
# CGG
# GGA
# GAT
# ATC
# TCC
# CCT
# CTC
# TCT
# CTA
# TAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAA
# AAG
# AGC
# GCC
# CCC
# CCG
# CGT
# GTA
# TAA
# AAA
# AAG
# AGA
# GAG
# AGG
# GGA
# GAA
# AAC
# ACT
# CTA
# TAC
# ACC
# CCT
# CTA
# TAG
# AGT
# GTA
# TAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCG
# CGT
# GTA
# TAT
# ATG
# TGT
# GTT
# TTC
# TCC
# CCA
# CAA
# AAG
# AGT
# GTT
# TTG
# TGC
# GCC
# CCA
# CAG
# AGT
# GTG
# TGC
# GCT
# CTA
# TAC
# ACT
# CTT
# TTA
# TAC
# ACT
# CTT
# TTT
# TTG
# TGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATT
# TTG
# TGC
# GCC
# CCC
# CCA
# CAA
# AAG
# AGG
# GGC
# GCT
# CTT
# TTT
# TTT
# TTC
# TCG
# CGG
# GGG
# GGG
# GGG
# GGA
# GAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATA
# TAG
# AGA
# GAA
# AAG
# AGA
# GAT
# ATG
# TGA
# GAT
# ATC
# TCA
# CAG
# AGA
# GAA
# AAT
# ATC
# TCT
# GGA
# GAA
# AAG
# AGA
# GAT
# ATG
# TGG
# GGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAT
# ATC
# TCA
# CAA
# AAG
# AGG
# GGC
# GCC
# CCC
# CCA
# CAA
# AAG
# AGA
# GAC
# ACA
# CAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTG
# TGG
# GGG
# GGT
# GTT
# TTC
# TCT
# CTC
# TCC
# CCA
# CAG
# AGG
# GGG
# GGT
# GTG
# TGG
# GGT
# GTT
# TTT
# TTC
# TCA
# CAG
# AGT
# GTA
# TAA
# AAG
# AGG
# GGG
# GGC
# GCA
# CAA
# AAC
# ACT
# CTT
# TTC
# TCA
# CAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGA
# GAA
# AAG
# AGA
# GAT
# ATT
# TTG
# TGG
# GGC
# GCA
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# CAG
# AGA
# GAG
# AGC
# GCA
# CAT
# ATA
# TAT
# ATG
# TGG
# GGA
# GAT
# ATG
# TGA
# GAA
# AAA
# AAG
# AGC
# GCG
# CGG
# GGA
# GAG
# AGG
# GGA
# GAA
# AAT
# ATC
# TCC
# CCG
# CGT
# GTA
# TAT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGA
# GAT
# ATA
# TAT
# ATA
# TAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTG
# TGC
# GCG
# CGT
# GTA
# TAC
# ACC
# CCA
# CAA
# AAA
# AAT
# ATA
# TAG
# AGT
# GTG
# TGT
# GTT
# TTC
# TCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACC
# CCT
# CTA
# TAT
# ATT
# TTA
# TAG
# AGG
# GGT
# GTG
# TGA
# GAC
# ACA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGA
# GAG
# AGG
# GGC
# GCA
# CAT
# ATT
# TTA
# TAA
# AAC
# ACA
# CAG
# AGC
# GCT
# CTG
# CCA
# CAG
# AGC
# GCT
# CTA
# TAC
# ACC
# CCT
# CTG
# TGG
# GGA
# GAG
# AGG
# GGG
# GGA
# GAG
# AGA
# GAT
# ATT
# TTC
# TCA
# CAC
# ACG
# CGA
# GAT
# ATG
# TGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAA
# AAC
# ACA
# CAG
# AGA
# GAA
# AAC
# ACA
# CAT
# ATA
# TAC
# ACT
# CTG
# TGA
# GAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAG
# AGA
# GAA
# AAG
# AGC
# GCA
# CAT
# ATG
# TGG
# GGT
# GTG
# TGT
# GTA
# TAT
# ATA
# TAC
# ACA
# CAG
# AGG
# GGA
# GAG
# AGC
# GCA
# CAT
# ATC
# TCT
# CTA
# TAC
# ACC
# CCA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAT
# ATC
# TCC
# CCT
# CTG
# TGT
# GTG
# TGT
# GTA
# TAA
# AAC
# ACA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAC
# ACC
# CCA
# CAG
# AGG
# GGG
# GGC
# GCA
# CAG
# AGG
# GGT
# GTC
# TCT
# CTT
# TTA
# TAA
# AAG
# AGA
# GAA
# AAC
# ACC
# CCA
# CAA
# AAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACG
# CGG
# GGA
# GAG
# AGC
# GCA
# CAA
# AAT
# ATG
# TGA
# GAA
# AAC
# ACC
# CCA
# CAG
# AGT
# GTA
# TAC
# ACA
# CAG
# AGA
# GAA
# AAG
# AGT
# GTT
# TTT
# TTG
# TGT
# GTT
# TTT
# TTG
# TGT
# GTA
# TAT
# ATC
# TCT
# CTC
# TCT
# CTA
# TAT
# ATC
# TCA
# CAG
# AGA
# GAG
# AGG
# GGC
# GCT
# CTG
# TGG
# GGT
# GTT
# TTT
# TTG
# TGT
# GTC
# TCA
# CAG
# AGA
# GAC
# ACA
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# ACT
# CTG
# TGC
# GCT
# CTC
# TCT
# CTA
# TAC
# ACG
# CGA
# GAT
# ATA
# TAC
# ACC
# CCG
# CGC
# GCA
# CAT
# ATA
# TAC
# ACA
# CAT
# ATG
# TGG
# GGC
# GCA
# CAC
# ACT
# CTG
# TGC
# GCA
# CAC
# ACA
# CAT
# ATA
# TAA
# AAT
# ATC
# TCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACC
# CCG
# CGT
# GTA
# TAA
# AAG
# AGG
# GGA
# GAG
# AGT
# GTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAG
# AGT
# GTG
# TGC
# GCA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAG
# AGT
# GTG
# TGT
# GTC
# TCC
# CCT
# CTA
# TAA
# AAG
# AGC
# GCA
# CAC
# ACC
# CCA
# CAG
# AGG
# GGT
# GTT
# TTC
# TCG
# CGC
# GCT
# CTG
# TGA
# GAC
# ACC
# CCT
# CTA
# TAA
# AAT
# ATC
# TCA
# CAT
# ATC
# TCT
# CTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAT
# ATG
# TGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGG
# GGT
# GTT
# TTC
# TCT
# CTC
# TCT
# CTA
# TAG
# AGG
# GGT
# GTG
# TGA
# GAT
# ATC
# TCA
# CAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATA
# TAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATT
# TTC
# TCA
# CAG
# AGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGC
# GCA
# CAC
# ACA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAC
# ACA
# CAA
# AAG
# AGG
# GGA
# GAT
# ATT
# TTC
# TCT
# CTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAG
# AGG
# CTA
# TAT
# ATC
# TCC
# CCA
# CAA
# AAT
# ATG
# TGA
# GAG
# AGA
# GAA
# AAG
# AGT
# GTC
# TCT
# CTG
# TGC
# GCT
# CTA
# TAT
# ATC
# TCT
# CTA
# TAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TCA
# CAC
# ACT
# CTT
# TTC
# TCT
# CTT
# TTA
# TAA
# AAA
# AAG
# AGG
# GGT
# GTG
# TGA
# GAC
# ACC
# CCT
# CTG
# TGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGA
# GAT
# ATG
# TGA
# GAA
# AAT
# ATG
# TGG
# GGA
# GAC
# ACT
# CTG
# TGA
# GAC
# ACC
# CCT
# CTT
# TTT
# TTG
# TGG
# GGG
# GGA
# GAT
# ATG
# TGA
# GAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCA
# CAG
# AGA
# GAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTA
# TAG
# AGC
# GCA
# CAG
# AGC
# GCA
# CAT
# ATA
# TAG
# AGA
# GAG
# AGG
# GGG
# GGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCT
# CTA
# TAC
# ACC
# CCT
# CTA
# TAT
# ATG
# TGG
# GGG
# GGA
# GAG
# AGA
# GAA
# AAG
# AGA
# GAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATC
# TCT
# CTA
# TAT
# ATC
# TCA
# CAT
# ATG
# TGT
# GTG
# TGC
# GCA
# CAC
# ACC
# CCA
# CAG
# AGT
# GTG
# TGC
# GCA
# CAT
# ATA
# TAC
# ACA
# CAT
# ATT
# TTG
# TGC
# GCA
# CAC
# ACT
# CTA
# TAC
# ACT
# CTC
# TCG
# CGG
# GGA
# GAA
# AAC
# ACC
# CCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACG
# CGG
# GGT
# GTA
# TAA
# AAG
# AGG
# GGA
# GAG
# AGA
# GAA
# CTG
# TGA
# GAC
# ACC
# CCT
# CTT
# TTT
# TTG
# TGG
# GGG
# GGA
# GAT
# ATG
# TGA
# GAG
# AGA
# GAT
# ATA
# TAG
# AGC
# GCA
# CAG
# AGA
# GAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTA
# TAG
# AGC
# GCA
# CAG
# AGC
# GCA
# CAT
# ATA
# TAG
# AGA
# GAG
# AGG
# GGG
# GGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCT
# CTA
# TAC
# ACC
# CCT
# CTA
# TAT
# ATG
# TGG
# GGG
# GGA
# GAG
# AGA
# GAA
# AAG
# AGA
# GAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATC
# TCT
# CTA
# TAT
# ATC
# TCA
# CAT
# ATG
# TGT
# GTG
# TGC
# GCA
# CAC
# ACC
# CCA
# CAG
# AGT
# GTG
# TGC
# GCA
# CAT
# ATA
# TAC
# ACA
# CAT
# ATT
# TTG
# TGC
# GCA
# CAC
# ACT
# CTA
# TAC
# ACT
# CTC
# TCG
# CGG
# GGA
# GAA
# AAC
# ACC
# CCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACG
# CGG
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# GGT
# GTA
# TAA
# AAG
# AGG
# GGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTC
# TCT
# CTT
# TTC
# TCC
# CCT
# CTC
# TCC
# CCA
# CAA
# AAC
# ACA
# CAG
# AGA
# GAG
# AGT
# GTA
# TAG
# AGG
# GGA
# GAT
# ATA
# TAC
# ACT
# CTG
# TGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGT
# GTT
# TTC
# TCA
# CAA
# AAG
# AGG
# GGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAT
# ATG
# TGA
# GAT
# ATG
# TGA
# GAG
# AGC
# GCT
# CTA
# TAC
# ACA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAG
# /tmp/ipykernel_12183/1716591771.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
#     df[str(result.name)] = result.curvature[0,:]
#     df[str(result.name)] = df[str(result.name)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[0])
#     df.to_csv(snakemake.output[1], index=True)
# else:
#     plt.savefig(snakemake.output[0])
#     plt.show()
#     df.to_csv(snakemake.output[1], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTodiValues(sequence, 'stability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[1])
#     df.to_csv(snakemake.output[2], index=True)
# else:
#     plt.savefig(snakemake.output[1])
#     plt.show()
#     df.to_csv(snakemake.output[2], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTotriValues(sequence, 'DNAse1_bendability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[3])
#     df.to_csv(snakemake.output[4], index=True)
# else:
#     plt.savefig(snakemake.output[3])
#     plt.show()
#     df.to_csv(snakemake.output[4], index=True)

# %%
# Out:
# LUZ7 t5 plus
