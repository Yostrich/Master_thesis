# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xd5\x07\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c3TSS_14-1_one/TSS_seq_14-1_enriched_one.minus.fa.out\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x16)}\x94\x8c\x05_name\x94h\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c?TSS_14-1_one/structural_properties/14-1_one_curvature.minus.png\x94\x8c?TSS_14-1_one/structural_properties/14-1_one_curvature.minus.csv\x94\x8c?TSS_14-1_one/structural_properties/14-1_one_stability.minus.png\x94\x8c?TSS_14-1_one/structural_properties/14-1_one_stability.minus.csv\x94\x8cATSS_14-1_one/structural_properties/14-1_one_bendability.minus.png\x94\x8cATSS_14-1_one/structural_properties/14-1_one_bendability.minus.csv\x94e}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x0414-1\x94\x8c\x03one\x94\x8c\x05minus\x94e}\x94(h\x0c}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94b\x8c\x05phage\x94hH\x8c\x05ident\x94hI\x8c\x04sign\x94hJub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bhgK\x01hiK\x01hkhdub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c#logs/notebooks/14-1_one.minus.ipynb\x94a}\x94(h\x0c}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bh}hzub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\n14-1.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list

def smooth(value_list, window):
    tempList = value_list + [0]*6
    print(tempList)
    newList = []
    for i in range(0, len(value_list)):
        end = i+window
        Sum = sum(tempList[i:end])/window
        newList.append(Sum)
    return newList

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
    df[str(result.name)] = result.curvature[0,:]
    df[str(result.name)] = df[str(result.name)].rolling(20).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[0])
    df.to_csv(snakemake.output[1], index=True)
else:
    plt.savefig(snakemake.output[0])
    plt.show()
    df.to_csv(snakemake.output[1], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTodiValues(sequence, 'stability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[2])
    df.to_csv(snakemake.output[3], index=True)
else:
    plt.savefig(snakemake.output[2])
    plt.show()
    df.to_csv(snakemake.output[3], index=True)

# %%
fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
for fasta in fasta_sequences:
    nameSeq, sequence = fasta.id, str(fasta.seq)
    result = seqTotriValues(sequence, 'DNAse1_bendability')
    df[str(nameSeq)] = result
    df[str(nameSeq)] = df[str(nameSeq)].rolling(50).mean()
df["mean"] = df.mean(axis=1)
if not(df.empty):
    df.plot(use_index=True)
    plt.legend('')
    plt.savefig(snakemake.output[4])
    df.to_csv(snakemake.output[5], index=True)
else:
    plt.savefig(snakemake.output[4])
    plt.show()
    df.to_csv(snakemake.output[5], index=True)
# Out:
# TCA
# CAG
# AGC
# GCC
# CCT
# CTC
# TCG
# CGC
# GCT
# CTG
# TGA
# GAT
# ATT
# TTG
# TGC
# GCG
# CGA
# GAT
# ATC
# TCT
# CTT
# TTG
# TGG
# GGC
# GCT
# CTG
# TGC
# GCG
# CGC
# GCG
# CGG
# GGA
# GAT
# ATT
# TTT
# TTT
# TTG
# TGT
# GTC
# TCG
# CGT
# GTT
# TTG
# TGA
# GAT
# ATT
# TTT
# TTG
# TGA
# GAT
# ATC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGT
# GTC
# TCA
# CAT
# ATT
# TTT
# TTC
# TCG
# CGG
# GGC
# GCT
# CTT
# TTC
# TCC
# CCT
# CTT
# TTT
# TTT
# TTG
# TGT
# GTT
# TTT
# TTG
# TGA
# GAA
# AAG
# AGG
# GGG
# GGT
# GTT
# TTT
# TTC
# TCG
# CGC
# GCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGA
# GAG
# AGG
# GGA
# GAG
# AGA
# GAT
# ATT
# TTA
# TAT
# ATG
# TGC
# GCC
# CCG
# CGA
# GAC
# ACA
# CAG
# AGT
# GTC
# TCA
# CAG
# AGA
# GAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGT
# GTG
# TGT
# GTC
# TCT
# CTG
# TGA
# GAT
# ATC
# TCG
# CGA
# GAA
# AAG
# AGA
# GAA
# AAA
# AAT
# ATT
# TTT
# TTC
# TCT
# CTG
# TGT
# GTA
# TAC
# ACA
# CAC
# ACC
# CCG
# CGA
# GAC
# ACG
# CGA
# GAA
# AAC
# ACG
# CGG
# GGT
# GTT
# TTG
# TGT
# GTG
# TGC
# GCT
# CTC
# TCG
# CGA
# GAC
# ACC
# CCG
# CGT
# GTC
# TCT
# CTG
# TGC
# GCT
# CTG
# TGC
# GCG
# CGG
# GGT
# GTG
# TGT
# GTC
# TTG
# TGC
# GCG
# CGG
# GGA
# GAT
# ATG
# TGC
# GCG
# CGG
# GGT
# GTC
# TCT
# CTT
# TTT
# TTC
# TCG
# CGC
# GCC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTT
# TTC
# TCC
# CCG
# CGG
# GGG
# GGG
# GGT
# GTG
# TGA
# GAA
# AAT
# ATT
# TTC
# TCG
# CGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGT
# GTC
# TCG
# CGG
# GGT
# GTC
# TCA
# CAT
# ATG
# TGG
# GGT
# GTC
# TCG
# CGG
# GGT
# GTT
# TTC
# TCC
# CCT
# CTT
# TTT
# TTT
# TTG
# TGT
# GTC
# TCT
# CTG
# TGA
# GAA
# AAG
# AGG
# GGG
# GGT
# GTT
# TTT
# TTC
# TCG
# CGC
# GCG
# CGT
# GTT
# TTT
# TTC
# TCA
# CAA
# AAT
# ATG
# TGG
# GGA
# GAG
# AGC
# GCT
# CTA
# TAT
# ATT
# TTT
# TTT
# TTG
# TGC
# GCC
# CCT
# CTT
# TTC
# TCA
# CAT
# ATT
# TTC
# TCA
# CAG
# AGA
# GAA
# AAT
# ATG
# TGG
# GGA
# GAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGC
# GCA
# CAT
# ATT
# TTT
# TTT
# TTC
# TCT
# CTT
# TTC
# TCC
# CCA
# CAC
# ACT
# CTA
# TAT
# ATT
# TTT
# TTC
# TCG
# CGG
# GGC
# GCA
# CAT
# ATT
# TTG
# TGA
# GAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAA
# AAA
# AAT
# ATT
# TTC
# TCC
# CCA
# CAG
# AGA
# GAT
# ATC
# TCC
# CCA
# CAA
# AAT
# ATC
# TCG
# CGC
# GCC
# CCT
# CTG
# TGC
# GCT
# CTA
# TAC
# ACC
# CCA
# CAG
# AGC
# TCG
# CGC
# GCT
# CTA
# TAC
# ACG
# CGG
# GGT
# GTA
# TAG
# AGC
# GCG
# CGA
# GAA
# AAG
# AGT
# GTC
# TCG
# CGT
# GTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAG
# AGG
# GGT
# GTC
# TCT
# CTT
# TTC
# TCG
# CGA
# GAA
# AAG
# AGC
# GCC
# CCG
# CGG
# GGT
# GTG
# TGA
# GAA
# AAC
# ACA
# CAG
# AGA
# GAT
# ATT
# TTC
# TCT
# CTC
# TCT
# CTG
# TGC
# GCT
# CTG
# TGC
# GCG
# CGT
# GTT
# TTC
# TCA
# CAT
# ATA
# TAT
# ATC
# TCG
# CGA
# GAT
# ATT
# TTC
# TCT
# CTC
# TCC
# CCT
# CTG
# TGT
# GTT
# TTT
# TTG
# TGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTT
# TTC
# TCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGG
# GGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACT
# CTA
# TAT
# ATA
# TAC
# ACG
# CGC
# GCC
# CCA
# CAG
# AGA
# GAA
# AAA
# AAT
# ATG
# TGG
# GGA
# GAA
# AAA
# AAA
# AAC
# ACG
# CGG
# GGT
# GTA
# TAG
# AGC
# GCA
# CAC
# ACT
# CTT
# TTT
# TTC
# TCG
# CGC
# GCA
# CAC
# ACT
# CTA
# TAC
# ACC
# CCG
# CGT
# GTT
# TTC
# TCG
# CGT
# GTC
# TCG
# CGG
# GGA
# GAT
# ATC
# TCG
# CGC
# GCA
# CAG
# AGA
# GAG
# AGG
# GGG
# GGT
# GTC
# TCA
# CAG
# AGG
# GGC
# GCT
# CTA
# TAC
# ACA
# CAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCA
# CAA
# AAC
# ACT
# CTG
# TGC
# GCG
# CGA
# GAC
# ACA
# CAT
# ATG
# TGA
# GAC
# ACT
# TAG
# AGT
# GTA
# TAT
# ATG
# TGG
# GGT
# GTC
# TCC
# CCG
# CGG
# GGT
# GTA
# TAT
# ATC
# TCT
# CTG
# TGG
# GGA
# GAC
# ACA
# CAC
# ACA
# CAT
# ATC
# TCC
# CCG
# CGT
# GTC
# TCT
# CTC
# TCC
# CCA
# CAG
# AGT
# GTG
# TGC
# GCA
# CAA
# AAA
# AAG
# AGG
# GGA
# GAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGT
# GTA
# TAG
# AGC
# GCA
# CAA
# AAT
# ATC
# TCC
# CCA
# CAT
# ATA
# TAC
# ACG
# CGG
# GGT
# GTG
# TGA
# GAT
# ATA
# TAC
# ACT
# CTC
# TCG
# CGC
# GCC
# CCA
# CAT
# ATT
# TTT
# TTC
# TCG
# CGT
# GTC
# TCA
# CAC
# ACC
# CCT
# CTC
# TCT
# CTT
# TTT
# TTA
# TAG
# AGT
# GTT
# TTG
# TGA
# GAT
# ATG
# TGA
# GAG
# AGC
# GCA
# CAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTA
# TAT
# ATT
# TTC
# TCC
# CCA
# CAT
# ATC
# TCT
# CTG
# TGC
# GCT
# CTC
# TCG
# CGC
# GCC
# CCA
# CAG
# AGG
# GGA
# GAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGC
# GCG
# CGC
# GCT
# CTT
# TTT
# TTT
# TTC
# TCG
# CGT
# GTC
# TCG
# CGG
# GGG
# GGA
# GAT
# ATA
# TAA
# AAA
# AAT
# ATG
# TGC
# GCC
# CCG
# CGA
# GAT
# ATG
# TGA
# GAT
# ATG
# TGT
# GTC
# TCT
# CTG
# TGC
# GCG
# CGT
# GTC
# TCG
# CGA
# GAG
# AGC
# GCA
# CAT
# ATC
# TCC
# CCA
# CAA
# AAA
# AAT
# ATG
# TGT
# GTC
# TCC
# CCA
# CAC
# ACG
# CGG
# GGA
# GAC
# ACG
# CGG
# GGA
# CCG
# CGA
# GAT
# ATT
# TTT
# TTG
# TGT
# GTC
# TCG
# CGC
# GCA
# CAA
# AAT
# ATC
# TCG
# CGA
# GAA
# AAC
# ACA
# CAC
# ACG
# CGC
# GCC
# CCC
# CCA
# CAG
# AGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCG
# CGC
# GCC
# CCG
# CGT
# GTC
# TCT
# CTT
# TTT
# TTC
# TCA
# CAA
# AAC
# ACA
# CAC
# ACG
# CGA
# GAT
# ATA
# TAT
# ATG
# TGT
# GTA
# TAC
# ACG
# CGA
# GAT
# ATA
# TAG
# AGG
# GGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATT
# TTC
# TCA
# CAT
# ATG
# TGT
# GTT
# TTT
# TTA
# TAA
# AAT
# ATC
# TCT
# CTC
# TCC
# CCA
# CAT
# ATT
# TTG
# TGA
# GAC
# ACT
# CTG
# TGA
# GAT
# ATA
# TAA
# AAT
# ATT
# TTA
# TAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTA
# TAA
# AAT
# ATC
# TCT
# CTG
# TGC
# GCC
# CCG
# CGA
# GAA
# AAA
# AAA
# AAG
# AGT
# GTT
# TTC
# TCC
# CCC
# CCG
# CGT
# GTA
# TAA
# AAA
# AAG
# AGA
# GAA
# AAT
# ATT
# TTA
# TAT
# ATT
# TTT
# TTC
# TCT
# CTC
# TCA
# CAG
# AGA
# GAA
# AAC
# ACT
# CTG
# TGA
# GAT
# ATT
# TTA
# TAG
# AGT
# GTT
# TTG
# TGT
# GTA
# TAA
# AAC
# ACT
# CTG
# TGT
# GTT
# TTA
# TAA
# AAT
# ATC
# TCT
# CTG
# TGA
# GAT
# ATG
# TGT
# GTA
# TAT
# ATG
# TGT
# GTG
# TGT
# GTT
# TTT
# TTG
# TGA
# GAA
# AAT
# ATC
# TCT
# CTC
# TCT
# CTT
# TTT
# TTT
# TTG
# CTG
# TGC
# GCT
# CTA
# TAC
# ACG
# CGG
# GGC
# GCC
# CCT
# CTT
# TTG
# TGG
# GGT
# GTT
# TTT
# TTC
# TCT
# CTT
# TTC
# TCG
# CGG
# GGT
# GTT
# TTG
# TGC
# GCT
# CTT
# TTC
# TCG
# CGG
# GGA
# GAA
# AAG
# AGT
# GTT
# TTT
# TTC
# TCG
# CGG
# GGT
# GTT
# TTT
# TTT
# TTC
# TCT
# CTT
# TTA
# TAC
# ACC
# CCA
# CAG
# AGC
# GCC
# CCA
# CAT
# ATG
# TGT
# GTT
# TTA
# TAG
# AGG
# GGC
# GCT
# CTC
# TCC
# CCT
# CTT
# TTG
# TGT
# GTT
# TTT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAA
# AAT
# ATT
# TTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTA
# TAT
# ATC
# TCG
# CGC
# GCT
# CTA
# TAA
# AAC
# ACT
# CTG
# TGT
# GTG
# TGG
# GGG
# GGT
# GTT
# TTT
# TTA
# TAT
# ATA
# TAA
# AAT
# ATA
# TAA
# AAC
# ACG
# CGG
# GGA
# GAA
# AAG
# AGT
# GTT
# TTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTA
# TAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGC
# GCA
# CAA
# AAA
# AAT
# ATT
# TTA
# TAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTG
# TGC
# GCT
# CTC
# TCT
# CTT
# TTT
# TTT
# TTT
# TTC
# TCA
# CAC
# ACC
# CCT
# CTT
# TTC
# TCG
# CGG
# GGT
# GTT
# TTT
# TTC
# TCG
# CGT
# GTG
# TGA
# GAT
# ATT
# TTT
# TTT
# TTG
# TGG
# GGC
# GCC
# CCT
# CTC
# TCT
# CTT
# TTT
# TTG
# TGT
# GTA
# TAT
# ATT
# TTC
# CCT
# CTT
# TTG
# TGG
# GGT
# GTG
# TGG
# GGC
# GCG
# CGT
# GTA
# TAG
# AGG
# GGT
# GTT
# TTT
# TTT
# TTG
# TGG
# GGT
# GTG
# TGT
# GTG
# TGG
# GGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGT
# GTC
# TCG
# CGG
# GGT
# GTG
# TGG
# GGA
# GAG
# AGA
# GAA
# AAG
# AGG
# GGT
# GTT
# TTA
# TAC
# ACT
# CTT
# TTC
# TCG
# CGC
# GCG
# CGG
# GGG
# GGC
# GCC
# CCA
# CAT
# ATT
# TTT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATT
# TTC
# TCC
# CCT
# CTT
# TTT
# TTT
# TTG
# TGG
# GGT
# GTT
# TTG
# TGA
# GAA
# AAG
# AGG
# GGG
# GGT
# GTT
# TTT
# TTC
# TCG
# CGC
# GCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGA
# GAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATA
# TAT
# ATT
# TTA
# TAC
# ACG
# CGC
# GCC
# CCC
# CCA
# CAC
# ACC
# CCT
# CTG
# TGA
# GAT
# ATC
# TCC
# CCA
# CAG
# AGA
# GAA
# AAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGC
# GCA
# CAC
# ACT
# CTT
# TTT
# TTT
# TTG
# TGT
# GTA
# TAA
# AAA
# AAT
# ATT
# TTA
# TAC
# ACT
# CTT
# TTC
# TCA
# CAC
# ACG
# CGA
# GAA
# AAC
# ACA
# CAT
# ATC
# TCT
# CTG
# TGC
# GCT
# CTT
# TTG
# TGG
# GGC
# GCC
# CCT
# CTT
# TTC
# TCT
# CTG
# TGA
# GAT
# ATA
# TAA
# AAG
# AGA
# GAC
# ACG
# CGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGT
# GTC
# TCA
# CAT
# ATC
# TCA
# CAG
# AGG
# GCG
# CGG
# GGC
# GCT
# CTG
# TGC
# GCT
# CTT
# TTG
# TGT
# GTT
# TTC
# TCC
# CCT
# CTT
# TTG
# TGG
# GGT
# GTC
# TCA
# CAG
# AGC
# GCT
# CTC
# TCT
# CTT
# TTC
# TCG
# CGC
# GCC
# CCT
# CTT
# TTG
# TGG
# GGG
# GGT
# GTC
# TCT
# CTG
# TGT
# GTT
# TTC
# TCG
# CGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGT
# GTC
# TCC
# CCA
# CAT
# ATG
# TGT
# GTT
# TTC
# TCT
# CTT
# TTA
# TAC
# ACT
# CTC
# TCC
# CCG
# CGG
# GGG
# GGA
# GAA
# AAT
# ATG
# TGT
# GTT
# TTT
# TTG
# TGA
# GAA
# AAA
# AAG
# AGG
# GGA
# GAT
# ATG
# TGG
# GGC
# GCT
# CTT
# TTA
# TAT
# ATT
# TTG
# TGG
# GGC
# GCC
# CCT
# CTG
# TGT
# GTG
# TGA
# GAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATT
# TTA
# TAT
# ATC
# TCT
# CTC
# TCT
# CTA
# TAA
# AAA
# AAC
# ACT
# CTA
# TAA
# AAT
# ATT
# TTG
# TGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATA
# TAC
# ACC
# CCT
# CTT
# TTT
# TTC
# TCG
# CGC
# GCC
# CCT
# CTG
# TGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCT
# CTC
# TCT
# CTA
# TAA
# AAA
# AAT
# ATA
# TAT
# ATT
# TTT
# TTT
# TTT
# TTC
# TCT
# CTT
# TTT
# TTC
# TCG
# CGG
# GGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTC
# TCC
# CCA
# CAG
# AGA
# GAC
# ACT
# CTC
# TCC
# CCA
# CAG
# AGG
# GGG
# GGA
# GAA
# AAC
# ACT
# CTT
# TTA
# TAT
# TTC
# TCG
# CGG
# GGG
# GGA
# GAT
# ATC
# TCG
# CGC
# GCC
# CCC
# CCC
# CCT
# CTC
# TCG
# CGA
# GAA
# AAC
# ACA
# CAC
# ACC
# CCA
# CAC
# ACA
# CAG
# AGT
# GTG
# TGC
# GCC
# CCT
# CTT
# TTC
# TCG
# CGT
# GTG
# TGA
# GAG
# AGT
# GTT
# TTA
# TAA
# AAA
# AAA
# AAT
# ATA
# TAT
# ATG
# TGT
# GTT
# TTC
# TCC
# CCG
# CGC
# GCC
# CCA
# CAT
# ATC
# TCG
# CGA
# GAA
# AAT
# ATG
# TGT
# GTT
# TTC
# TCC
# CCT
# CTT
# TTT
# TTA
# TAT
# ATA
# TAA
# AAC
# ACG
# CGT
# GTA
# TAC
# ACA
# CAG
# AGT
# GTT
# TTA
# TAT
# ATG
# TGC
# GCT
# CTT
# TTT
# TTA
# TAC
# ACC
# CCT
# CTC
# TCT
# CTG
# TGC
# GCG
# CGC
# GCA
# CAG
# AGG
# GGA
# GAA
# AAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATA
# TAC
# ACT
# CTA
# TAT
# ATC
# TCA
# CAG
# AGC
# GCT
# CTG
# TGA
# GAC
# ACT
# CTC
# TCG
# CGC
# GCC
# CCA
# CAA
# AAA
# AAG
# AGC
# GCG
# CGA
# GAG
# AGC
# GCG
# CGA
# GAA
# AAT
# ATT
# TTT
# TTA
# TAA
# AAT
# ATC
# TCC
# CCA
# CAA
# AAC
# ACT
# CTT
# TTT
# TTA
# TAC
# ACT
# CTT
# TTC
# TCG
# CGG
# GGC
# GCA
# CAG
# AGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTG
# TGG
# GGC
# GCC
# CCG
# CGA
# GAT
# ATA
# TAC
# ACT
# CTA
# TAG
# AGA
# GAG
# AGC
# GCC
# CCG
# CGC
# GCC
# CCG
# CGC
# GCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACT
# TTC
# TCT
# CTG
# TGC
# GCG
# CGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAT
# ATG
# TGT
# GTC
# TCG
# CGC
# GCC
# CCG
# CGA
# GAA
# AAG
# AGG
# GGT
# GTT
# TTT
# TTT
# TTG
# TGA
# GAT
# ATG
# TGG
# GGA
# GAG
# AGT
# GTT
# TTG
# TGG
# GGT
# GTC
# TCA
# CAT
# ATT
# TTT
# TTT
# TTG
# TGC
# GCG
# CGA
# GAT
# ATC
# TCC
# CCT
# CTC
# TCT
# CTG
# TGT
# GTT
# TTT
# TTT
# TTG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAT
# ATT
# TTT
# TTC
# TCG
# CGT
# GTT
# TTT
# TTG
# TGG
# GGG
# GGC
# GCT
# CTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTT
# TTG
# TGT
# GTC
# TCG
# CGC
# GCC
# CCC
# CCC
# CCG
# CGT
# GTT
# TTG
# TGA
# GAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATT
# TTA
# TAT
# ATG
# TGC
# GCC
# CCT
# CTA
# TAG
# AGG
# GGT
# GTC
# TCG
# CGA
# GAT
# ATG
# TGC
# GCT
# CTG
# TGC
# GCG
# CGT
# GTG
# TGT
# GTC
# TCT
# CTA
# TAC
# ACA
# CAT
# ATC
# TCT
# CTA
# TAT
# ATT
# TTT
# TTC
# TCA
# CAT
# ATC
# TCA
# CAG
# AGA
# GAT
# ATT
# TTG
# TGA
# GAT
# ATC
# TCA
# CAC
# ACA
# CAA
# AAA
# AAG
# AGC
# GCC
# CCG
# CGA
# GAC
# ACG
# CGA
# GAA
# AAC
# ACG
# CGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCT
# CTG
# TGA
# GAT
# ATG
# TGT
# GTG
# TGA
# GAA
# AAA
# AAA
# AAC
# ACA
# CAC
# ACC
# CCG
# CGC
# GCA
# CAG
# AGA
# CTT
# TTG
# TGC
# GCT
# CTG
# TGT
# GTA
# TAG
# AGG
# GGC
# GCT
# CTG
# TGC
# GCG
# CGA
# GAC
# ACG
# CGC
# GCC
# CCT
# CTC
# TCG
# CGC
# GCG
# CGT
# GTC
# TCA
# CAT
# ATG
# TGT
# GTT
# TTC
# TCA
# CAG
# AGA
# GAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGC
# GCA
# CAG
# AGA
# GAG
# AGT
# GTC
# TCG
# CGC
# GCT
# CTG
# TGC
# GCG
# CGC
# GCG
# CGG
# GGC
# GCC
# CCG
# CGA
# GAC
# ACG
# CGC
# GCG
# CGC
# GCT
# CTG
# TGG
# GGA
# GAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TCG
# CGG
# GGT
# GTC
# TCG
# CGG
# GGA
# GAC
# ACT
# CTG
# TGA
# GAC
# ACC
# CCG
# CGT
# GTC
# TCA
# CAC
# ACC
# CCC
# CCA
# CAG
# AGT
# GTA
# TAA
# AAT
# ATG
# TGG
# GGC
# GCC
# CCA
# CAC
# ACT
# CTT
# TTT
# TTG
# TGT
# GTT
# TTC
# TCT
# CTT
# TTT
# TTA
# TAT
# ATC
# TCG
# CGG
# GGA
# GAC
# ACA
# CAT
# ATA
# TAA
# AAG
# AGC
# GCT
# CTG
# TGC
# GCC
# CCC
# CCT
# CTC
# TCC
# CCA
# CAA
# AAT
# ATG
# TGA
# GAG
# AGA
# GAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTC
# TCT
# CTG
# TGC
# GCC
# CCG
# CGA
# GAG
# AGT
# GTC
# TCG
# CGC
# GCA
# CAG
# AGA
# GAG
# AGG
# GGC
# GCT
# CTG
# TGG
# GGT
# GTT
# TTG
# TGT
# GTT
# TTG
# TGT
# GTT
# TTA
# TAG
# AGT
# GTC
# TCG
# CGC
# GCG
# CGC
# GCT
# CTT
# TTC
# GCT
# CTG
# TGT
# GTT
# TTT
# TTA
# TAC
# ACG
# CGG
# GGC
# GCC
# CCT
# CTC
# TCG
# CGA
# GAC
# ACT
# CTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGG
# GGT
# GTG
# TGT
# GTC
# TCG
# CGT
# GTT
# TTT
# TTC
# TCT
# CTG
# TGC
# GCC
# CCG
# CGA
# GAT
# ATG
# TGG
# GGT
# GTC
# TCC
# CCA
# CAT
# ATT
# TTT
# TTG
# TGG
# GGA
# GAG
# AGC
# GCT
# CTA
# TAG
# AGT
# GTC
# TCA
# CAT
# ATG
# TGT
# GTC
# TCG
# CGC
# GCA
# CAA
# AAT
# ATC
# TCC
# CCT
# CTC
# TCT
# CTT
# TTT
# TTT
# TTT
# TTG
# TGG
# GGA
# GAG
# AGT
# GTG
# TGT
# GTT
# TTT
# TTC
# TCG
# CGC
# GCG
# CGT
# GTT
# TTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGA
# GAG
# AGG
# GGT
# GTA
# TAA
# AAC
# ACT
# CTA
# TAT
# ATA
# TAC
# ACC
# CCT
# CTC
# TCA
# CAG
# AGT
# GTC
# TCA
# CAT
# ATC
# TCT
# CTC
# TCA
# CAT
# ATA
# TAG
# AGA
# GAG
# AGT
# GTA
# TAA
# AAA
# AAG
# AGC
# GCA
# CAC
# ACT
# CTT
# TTC
# TCT
# CTG
# TGA
# GAG
# AGG
# GGA
# GAA
# AAC
# ACT
# CTA
# TAT
# ATC
# TCT
# CTG
# TGA
# GAA
# AAA
# AAT
# ATT
# TTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAG
# AGG
# GGA
# GAA
# AAT
# ATT
# TTG
# TGT
# GTC
# TCG
# CGC
# GCC
# CCA
# CAG
# AGA
# GAG
# AGC
# GCC
# CCA
# CAG
# AGT
# GTC
# TCG
# CGA
# GAT
# ATG
# TGT
# GTG

# %%
# Out:
# LUZ7 t5 plus
