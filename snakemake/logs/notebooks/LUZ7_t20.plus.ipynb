# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x18\x08\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c2TSS_LUZ7_t20/TSS_seq_LUZ7_enriched_t20.plus.fa.out\x94\x8c\'TSS_LUZ7_t20/random_seq_LUZ7_t20.fa.out\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x11\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x17)}\x94\x8c\x05_name\x94h\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c>TSS_LUZ7_t20/structural_properties/LUZ7_t20_curvature.plus.csv\x94\x8c>TSS_LUZ7_t20/structural_properties/LUZ7_t20_stability.plus.csv\x94\x8c@TSS_LUZ7_t20/structural_properties/LUZ7_t20_bendability.plus.csv\x94\x8cITSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_curvature.plus.csv\x94\x8cITSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_stability.plus.csv\x94\x8cKTSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_bendability.plus.csv\x94e}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x04LUZ7\x94\x8c\x03t20\x94\x8c\x04plus\x94e}\x94(h\r}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94b\x8c\x05phage\x94hI\x8c\x05ident\x94hJ\x8c\x04sign\x94hKub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bhhK\x01hjK\x01hlheub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c"logs/notebooks/LUZ7_t20.plus.ipynb\x94a}\x94(h\r}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bh~h{ub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\nLUZ7.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0]
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0,0]
def getCurvature(seq):
    return CurvedDNA(seq, 'trifonov').curvature[0,:].tolist()
def savePropertiesToCsv(propertyfunc, fastaFile, window,outCSV,bp_upstream,bp_downstream):
    fasta_sequences = SeqIO.parse(open(fastaFile),'fasta')
    df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
    for fasta in fasta_sequences:
        nameSeq, sequence = fasta.id, str(fasta.seq)
        df[str(nameSeq)] = propertyfunc(sequence)
        df[str(nameSeq)] = df[str(nameSeq)].rolling(window).median()
    df["mean"] = df.mean(axis=1)
    df.to_csv(outCSV, index=True)

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
partial_stability = lambda y: seqTodiValues(y, "stability")
partial_bendability = lambda y: seqTotriValues(y, "DNAse1_bendability")
savePropertiesToCsv(getCurvature,snakemake.input[0], 20, snakemake.output[0],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[0], 20, snakemake.output[1],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[0], 20, snakemake.output[2],bp_upstream,bp_downstream)
savePropertiesToCsv(getCurvature,snakemake.input[1], 20, snakemake.output[3],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[1], 20, snakemake.output[4],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[1], 20, snakemake.output[5],bp_upstream,bp_downstream)
# Out:
# AGA
# GAT
# ATC
# TCC
# CCC
# CCG
# CGT
# GTT
# TTA
# TAG
# AGT
# GTC
# TCA
# CAA
# AAC
# ACT
# CTA
# TAG
# AGC
# GCC
# CCG
# CGA
# GAT
# ATT
# TTA
# TAG
# AGT
# GTA
# TAC
# ACC
# CCC
# CCG
# CGT
# GTG
# TGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAA
# AAC
# ACT
# CTC
# TCA
# CAG
# AGG
# GGA
# GAT
# ATT
# TTG
# TGC
# GCT
# CTT
# TTT
# TTA
# TAT
# ATC
# TCA
# CAT
# ATG
# TGG
# GGC
# GCA
# CAT
# ATT
# TTT
# TTG
# TGG
# GGC
# GCT
# CTG
# TGC
# GCT
# CTA
# TAC
# ACT
# CTA
# TAA
# AAG
# AGC
# GCA
# CAG
# AGT
# GTG
# TGA
# GAA
# AAC
# ACT
# CTT
# TTG
# TGC
# GCT
# CTG
# TGG
# GGA
# GAG
# AGA
# GAG
# AGT
# GTC
# TCC
# CCA
# CAA
# AAT
# ATG
# TGC
# GCC
# CCT
# CTT
# TTG
# TGG
# GGA
# GAA
# AAA
# AAA
# AAG
# AGC
# GCA
# CAA
# AAC
# ACC
# CCC
# CCT
# CTG
# TGA
# GAC
# ACT
# CTT
# TTG
# TGT
# GTG
# TGG
# GGG
# GGG
# GGT
# GTT
# TTT
# TTA
# TAC
# ACT
# CTC
# TCG
# CGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGT
# GTG
# TGT
# GTT
# TTG
# TGA
# GAT
# ATC
# TCA
# CAG
# AGT
# GTC
# TCT
# CTG
# TGA
# GAT
# ATA
# TAA
# AAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACT
# CTG
# TGA
# GAT
# ATC
# TCT
# CTC
# TCG
# CGC
# GCT
# CTG
# TGG
# GGC
# GCT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGG
# GGT
# GTT
# TTG
# TGG
# GGC
# GAG
# AGC
# GCA
# CAG
# AGC
# GCG
# CGA
# GAA
# AAG
# AGC
# GCG
# CGA
# GAG
# AGA
# GAC
# ACT
# CTC
# TCC
# CCT
# CTG
# TGC
# GCC
# CCC
# CCT
# CTC
# TCC
# CCG
# CGA
# GAT
# ATA
# TAG
# AGC
# GCC
# CCA
# CAG
# AGC
# GCA
# CAG
# AGA
# GAG
# AGC
# GCA
# CAA
# AAC
# ACA
# CAC
# ACG
# CGG
# GGG
# GGC
# GCA
# CAG
# AGC
# GCA
# CAG
# AGG
# GGG
# GGC
# GCT
# CTG
# TGT
# GTC
# TCC
# CCA
# CAT
# ATG
# TGT
# GTT
# TTA
# TAC
# ACT
# CTG
# TGG
# GGG
# GGG
# GGA
# GAG
# AGC
# GCA
# CAT
# ATG
# TGG
# GGC
# GCC
# CCA
# CAT
# ATG
# TGG
# GGT
# GTG
# TGG
# GGC
# GCT
# CTG
# TGG
# GGG
# GGA
# GAT
# ATC
# TCA
# CAC
# ACC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGT
# GTG
# TGT
# GTA
# TAC
# ACG
# CGA
# GAG
# AGT
# GTT
# TTG
# TGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTC
# TCA
# CAT
# ATT
# TTT
# TTC
# TCG
# CGG
# GGT
# GTT
# TTC
# TCC
# CCT
# CTC
# TCC
# CCG
# CGG
# GGT
# GTA
# TAG
# AGT
# GTG
# TGG
# GGG
# GGT
# GTA
# TAG
# AGC
# GCG
# CGT
# GTT
# TTC
# TCT
# CTT
# TTT
# TTG
# TGA
# GAT
# ATC
# TCT
# CTC
# TCT
# CTT
# TTC
# TCC
# CCA
# CAC
# ACC
# CCT
# CTT
# TTG
# TGG
# GGC
# GCA
# CAA
# AAG
# AGC
# GCC
# CCA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGT
# GTG
# TGT
# GTA
# TAA
# AAT
# ATC
# TCC
# CCG
# GCG
# CGG
# GGC
# GCA
# CAG
# AGC
# GCG
# CGG
# GGC
# GCC
# CCA
# CAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGT
# GTG
# TGG
# GGG
# GGT
# GTT
# TTG
# TGC
# GCG
# CGG
# GGG
# GGA
# GAT
# ATG
# TGG
# GGC
# GCG
# CGG
# GGA
# GAT
# ATT
# TTC
# TCG
# CGG
# GGA
# GAC
# ACA
# CAC
# ACT
# CTT
# TTC
# TCT
# CTT
# TTC
# TCT
# CTT
# TTC
# TCC
# CCT
# CTC
# TCG
# CGT
# GTC
# TCT
# CTT
# TTC
# TCT
# CTA
# TAC
# ACG
# CGG
# GGT
# GTG
# TGT
# GTT
# TTG
# TGC
# GCC
# CCT
# CTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGG
# GGC
# GCA
# CAG
# AGC
# GCA
# CAT
# ATT
# TTG
# TGA
# GAC
# ACC
# CCA
# CAT
# ATG
# TGG
# GGC
# GCA
# CAC
# ACG
# CGG
# GGA
# GAG
# AGC
# GCT
# CTT
# TTG
# TGT
# GTC
# TCC
# CCA
# CAC
# ACG
# CGC
# GCC
# CCG
# CGG
# GGT
# GTG
# TGT
# GTT
# TTG
# TGG
# GGA
# GAA
# AAC
# ACG
# CGG
# GGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCA
# CAG
# AGA
# GAC
# ACC
# CCC
# CCA
# CAG
# AGT
# GTT
# TTG
# TGG
# GGG
# GGT
# GTA
# TAG
# AGC
# GCA
# CAC
# ACG
# CGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGC
# GCA
# CAG
# AGG
# GGA
# GAC
# ACT
# CTT
# TTC
# TCC
# CCA
# CAG
# AGT
# GTT
# TTC
# TCG
# CGG
# GGA
# GAA
# AAC
# ACG
# CGC
# GCT
# CTG
# TGC
# GCG
# CGG
# GGC
# GCA
# CAG
# AGA
# GAG
# AGA
# GAA
# AAG
# AGC
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# ...
# TGG
# GGC
# GCT
# CTA
# TAC
# ACA
# CAG
# AGT
# GTT
# TTG
# TGC
# GCC
# CCT
# CTC
# TCT
# CTT
# TTC
# TCA
# CAT
# ATT
# TTG
# TGC
# GCG
# CGG
# GGC
# GCG
# CGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATG
# TGG
# GGA
# GAA
# AAT
# ATC
# TCC
# CCA
# CAA
# AAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTT
# TTC
# TCC
# CCC
# CCT
# CTG
# TGT
# GTG
# TGC
# GCT
# CTT
# AAT
# ATC
# TCT
# CTC
# TCT
# CTT
# TTG
# TGA
# GAA
# AAT
# ATG
# TGG
# GGT
# GTC
# TCG
# CGA
# GAA
# AAT
# ATT
# TTC
# TCA
# CAT
# ATT
# TTT
# TTC
# TCG
# CGT
# GTT
# TTT
# TTC
# TCT
# CTC
# TCT
# CTC
# TCT
# CTG
# TGG
# GGT
# GTT
# TTA
# TAA
# AAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACA
# CAG
# AGA
# GAG
# AGC
# GCC
# CCA
# CAC
# ACC
# CCG
# CGG
# GGG
# GGT
# GTA
# TAA
# AAG
# AGG
# GGG
# GGT
# GTG
# TGG
# GGC
# GCT
# CTC
# TCT
# CTA
# TAA
# AAT
# ATA
# TAT
# ATA
# TAC
# ACA
# CAT
# ATA
# TAG
# AGT
# GTT
# TTA
# TAG
# AGT
# GTT
# TTT
# TTA
# TAT
# ATC
# TCG
# CGT
# GTT
# TTT
# TTG
# TGG
# GGA
# GAA
# AAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGG
# GGC
# GCT
# CTA
# TAC
# ACA
# CAG
# AGT
# GTT
# TTG
# TGC
# GCC
# CCT
# CTC
# TCT
# CTT
# TTC
# TCA
# CAT
# ATT
# TTG
# TGC
# GCG
# CGG
# GGC
# GCG
# CGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATG
# TGG
# GGA
# GAA
# AAT
# ATC
# TCC
# CCA
# CAA
# AAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTT
# TTC
# TCC
# CCC
# CCT
# CTG
# TGT
# GTG
# TGC
# GCT
# CTT
# TTG
# TGT
# GTG
# TGC
# GCA
# CAT
# ATC
# TCA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGT
# GTA
# TAC
# ACC
# CCC
# CCT
# CTC
# TCG
# CGT
# GTC
# TCT
# CTT
# TTC
# TCT
# CTC
# TCC
# CCA
# CAG
# AGT
# GTT
# GTT
# TTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACG
# CGA
# GAA
# AAC
# ACC
# CCA
# CAT
# ATC
# TCA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCA
# CAC
# ACC
# CCG
# CGT
# GTA
# TAC
# ACA
# CAC
# ACA
# CAC
# ACT
# CTG
# TGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCA
# CAC
# ACA
# CAG
# AGG
# GGC
# GCA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGC
# GCA
# CAG
# AGC
# GCA
# CAA
# AAC
# ACA
# CAA
# AAC
# ACG
# CGT
# GTA
# TAG
# AGG
# GGG
# GGG
# GGA
# GAT
# ATC
# TCT
# CTT
# TTA
# TAC
# ACC
# CCA
# CAT
# ATC
# TCC
# CCG
# CGG
# GGG
# GGA
# GAA
# AAC
# ACG
# CGG
# GGG
# GGT
# GTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCC
# CCA
# CAG
# AGA
# GAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTG
# TGA
# GAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAA
# AAG
# AGT
# GTT
# TTG
# TGC
# GCG
# CGA
# GAC
# ACA
# CAA
# AAT
# ATA
# TAG
# AGA
# GAG
# AGT
# GTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTC
# TCA
# CAC
# ACC
# CCA
# CAT
# ATC
# TCA
# CAC
# ACC
# CCA
# CAT
# ATG
# TGA
# GAA
# AAT
# ATA
# TAT
# ATC
# TCG
# CGT
# GTA
# TAA
# AAT
# ATA
# TAT
# ATC
# TCC
# CCC
# CCC
# CCA
# CAA
# AAT
# ATA
# TAC
# ACT
# CTC
# TCA
# CAT
# ATG
# TGC
# GCA
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# AGC
# GCA
# CAT
# ATA
# TAG
# AGG
# GGA
# GAG
# AGC
# GCT
# CTT
# TTT
# TTC
# TCG
# CGA
# GAA
# AAG
# AGG
# GGA
# GAT
# ATT
# TTC
# TCA
# CAA
# AAC
# ACC
# CCA
# CAC
# ACG
# CGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCG
# CGC
# GCT
# CTT
# TTT
# TTG
# TGT
# GTT
# TTC
# TCA
# CAT
# ATA
# TAT
# ATC
# TCA
# CAC
# ACC
# CCG
# CGT
# GTT
# TTG
# TGC
# GCA
# CAA
# AAG
# AGA
# GAC
# ACG
# CGG
# GGA
# GAT
# ATC
# TCG
# CGA
# GAT
# ATG
# TGA
# GAC
# ACA
# CAA
# AAT
# ATG
# TGT
# GTT
# TTG
# TGC
# GCG
# CGG
# GGA
# GAA
# AAG
# AGT
# GTC
# TCG
# CGC
# GCA
# CAG
# AGA
# GAC
# ACC
# CCT
# CTT
# TTC
# TCA
# CAG
# AGA
# GAG
# AGT
# GTC
# TCG
# CGG
# GGC
# GCT
# CTG
# TGG
# GGT
# GTT
# TTG
# TGA
# GAC
# ACG
# CGA
# GAT
# ATG
# TGG
# GGT
# GTC
# TCT
# CTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAC
# ACC
# CCT
# CTT
# TTC
# TCA
# CAC
# ACC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGC
# GCT
# CTG
# TGC
# GCC
# CCA
# CAT
# ATT
# TTT
# TTG
# TGG
# GGT
# GTA
# TAC
# ACA
# CAG
# AGC
# GCG
# CGA
# GAT
# ATG
# TGT
# GTA
# TAG
# AGG
# GGG
# GGA
# GAA
# AAT
# ATG
# TGC
# GCC
# CCG
# CGT
# GTC
# TCA
# CAC
# ACT
# CTT
# TTT
# TTC
# TCA
# CAT
# ATA
# TAG
# AGT
# GTT
# TTC
# TCT
# CTC
# TCG
# CGA
# GAA
# AAA
# AAG
# TCA
# CAG
# AGC
# GCG
# CGG
# GGC
# GCA
# CAG
# AGT
# GTA
# TAC
# ACT
# CTG
# TGG
# GGC
# GCA
# CAG
# AGA
# GAC
# ACA
# CAC
# ACA
# CAG
# AGC
# GCG
# CGA
# GAA
# AAG
# AGT
# GTC
# TCT
# CTG
# TGT
# GTC
# TCG
# CGT
# GTG
# TGA
# GAT
# ATG
# TGT
# GTA
# TAG
# AGA
# GAA
# AAG
# AGT
# GTT
# TTG
# TGA
# GAA
# AAG
# AGT
# GTT
# TTG
# TGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGT
# GTT
# TTC
# TCC
# CCG
# CGG
# GGG
# GGT
# GTA
# TAA
# AAC
# ACC
# CCG
# CGA
# GAG
# AGC
# GCC
# CCG
# CGT
# GTG
# TGG
# GGT
# GTC
# TCA
# CAT
# ATA
# TAC
# ACC
# CCA
# CAC
# ACT
# CTG
# TGC
# GCA
# CAA
# AAC
# ACT
# CTC
# TCG
# CGT
# GTT
# TTG
# TGT
# GTC
# TCC
# CCT
# CTG
# TGA
# GAA
# AAT
# ATC
# TCA
# CAG
# AGA
# GAC
# ACG
# CGG
# GGT
# GTC
# TCT
# CTT
# TTC
# TCA
# CAT
# ATC
# TCC
# CCG
# CGA
# GAC
# ACA
# CAT
# ATG
# TGA
# GAT
# ATT
# TTC
# TCG
# CGC
# GCA
# CAG
# AGC
# GCA
# CAT
# ATC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCT
# CTT
# TTG
# TGG
# GGT
# GTT
# TTG
# TGA
# GAA
# AAC
# ACG
# CGT
# GTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCT
# CTT
# TTC
# TCC
# CCC
# CCT
# CTG
# TGC
# GCT
# CTT
# TTT
# TTG
# TGA
# GAG
# AGT
# GTG
# TGC
# GCG
# CGG
# GGC
# GCC
# CCT
# CTC
# TCG
# CGT
# GTA
# TAC
# ACT
# CTT
# TCT
# CTT
# TTG
# TGG
# GGT
# GTT
# TTG
# TGA
# GAA
# AAC
# ACG
# CGT
# GTG
# TGT
# GTC
# TCG
# CGA
# GAT
# ATC
# TCT
# CTT
# TTC
# TCC
# CCC
# CCT
# CTG
# TGC
# GCT
# CTT
# TTT
# TTG
# TGA
# GAG
# AGT
# GTG
# TGC
# GCG
# CGG
# GGC
# GCC
# CCT
# CTC
# TCG
# CGT
# GTA
# TAC
# ACT
# CTT
# TTC
# TCT
# CTT
# TTC
# TCT
# CTT
# TTC
# TCA
# CAC
# ACG
# CGA
# GAA
# AAG
# AGT
# GTC
# TCA
# CAT
# ATA
# TAC
# ACG
# CGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCG
# CGG
# GGT
# GTC
# TCA
# CAG
# AGG
# GGC
# GCC
# CCA
# CAT
# ATG
# TGC
# GCA
# CAC
# ACC
# CCC
# CCC
# CCT
# CTG
# TGA
# GAA
# AAG
# AGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCC
# CCG
# CGA
# GAG
# AGC
# GCA
# CAA
# AAG
# AGG
# GGG
# GGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGC
# GCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTA
# TAG
# AGA
# GAC
# ACG
# CGT
# GTT
# TTC
# TCA
# CAC
# ACC
# CCT
# CTT
# TTC
# TCC
# CCA
# CAG
# AGG
# GGC
# GCA
# CAC
# ACC
# CCG
# CGG
# GGA
# GAC
# ACT
# CTC
# TCC
# CCA
# CAC
# ACT
# CTG
# TGC
# GCT
# CTT
# TTT
# TTG
# TGT
# GTA
# TAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATC
# TCC
# CCT
# CTT
# TTG
# TGG
# GGC
# GCG
# CGT
# GTT
# TTA
# TAA
# AAA
# AAC
# ACG
# CGG
# GCG
# CGG
# GGT
# GTC
# TCA
# CAG
# AGG
# GGC
# GCC
# CCA
# CAT
# ATG
# TGC
# GCA
# CAC
# ACC
# CCC
# CCC
# CCT
# CTG
# TGA
# GAA
# AAG
# AGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCC
# CCG
# CGA
# GAG
# AGC
# GCA
# CAA
# AAG
# AGG
# GGG
# GGA
# GAA
# AAC
# ACT
# CTT
# TTC
# TCT
# CTC
# TCG
# CGC
# GCA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTA
# TAG
# AGA
# GAC
# ACG
# CGT
# GTT
# TTC
# TCA
# CAC
# ACC
# CCT
# CTT
# TTC
# TCC
# CCA
# CAG
# AGG
# GGC
# GCA
# CAC
# ACC
# CCG
# CGG
# GGA
# GAC
# ACT
# CTC
# TCC
# CCA
# CAC
# ACT
# CTG
# TGC
# GCT
# CTT
# TTT
# TTG
# TGT
# GTA
# TAC
# ACA
# CAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATC
# TCC
# CCT
# CTT
# TTG
# TGG
# GGC
# GCG
# CGT
# GTT
# TTA
# TAA
# AAA
# AAC
# ACG
# CGG
# GGT
# GTG
# TGT
# GTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAC
# ACC
# CCA
# CAG
# AGA
# GAT
# ATG
# TGA
# GAT
# ATC
# TCA
# CAT
# ATG
# TGT
# GTT
# TTG
# TGC
# GCG
# CGG
# GGG
# GGT
# GTT
# TTG
# TGG
# GGG
# GGT
# GTG
# TGC
# GCA
# CAG
# AGT
# GTG
# TGC
# GCG
# CGT
# GTA
# TAA
# AAT
# ATC
# TCC
# CCA
# CAC
# ACC
# CCG
# CGC
# GCC
# CCT
# CTT
# TTG
# TGT
# GTA
# TAT
# ATA
# TAC
# ACC
# CCG
# CGT
# GTG
# TGT
# GTC
# TCT
# CTT
# TTC
# TCG
# CGA
# GTT
# TTG
# TGG
# GGC
# GCT
# CTG
# TGC
# GCT
# CTT
# TTC
# TCA
# CAC
# ACA
# CAC
# ACC
# CCG
# CGA
# GAA
# AAC
# ACC
# CCT
# CTT
# TTC
# TCT
# CTC
# TCC
# CCG
# CGA
# GAA
# AAG
# AGT
# GTG
# TGG
# GGC
# GCA
# CAG
# AGT
# GTC
# TCA
# CAT
# ATC
# TCA
# CAT
# ATC
# TCA
# CAG
# AGT
# GTT
# TTC
# TCA
# CAG
# AGC
# GCC
# CCT
# CTG
# TGA
# GAA
# AAC
# ACG
# CGT
# GTT
# TTG
# TGA
# GAT
# ATC
# TCG
# CGC
# GCC
# CCT
# CTT
# TTC
# TCT
# CTG
# TGA
# GAT
# ATA
# TAG
# AGA
# GAT
# ATG
# TGT
# GTC
# TCA
# CAG
# AGC
# GCA
# CAT
# ATT
# TTC
# TCA
# CAG
# AGA
# GAA
# AAC
# ACG
# CGT
# GTG
# TGA
# GAG
# AGT
# GTC
# TCG
# CGG
# GGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGT
# GTG
# TGT
# GTC
# TCT
# CTG
# TGT
# GTT
# TTC
# TCC
# CCA
# CAG
# AGG
# GGA
# GAT
# ATC
# TCA
# CAG
# AGG
# GGT
# GTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAG
# AGC
# GCT
# CTT
# TTC
# TCG
# CGA
# GAC
# ACT
# CTT
# TTG
# TGT
# GTT
# TTG
# TGT
# GTA
# TAC
# ACG
# CGC
# GCA
# CAC
# ACT
# CTG
# TGA
# GAC
# ACG
# CGT
# GTA
# TAG
# AGC
# GCT
# CTG
# TGG
# GGC
# GCG
# CGA
# GAT
# ATG
# TGT
# GTC
# TCC
# CCT
# CTT
# TTC
# TCG
# CGA
# GAT
# ATG
# TGC
# GCA
# CAT
# ATA
# TAG
# AGT
# GTT
# TTC
# TCT
# CTG
# TGC
# GCA
# CAT
# ATC
# TCG
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# ATG
# TGT
# GTA
# TAC
# ACC
# CCC
# CCA
# CAT
# ATC
# TCC
# CCA
# CAG
# AGC
# GCT
# CTT
# TTG
# TGA
# GAA
# AAC
# ACT
# CTT
# TTA
# TAC
# ACC
# CCC
# CCT
# CTC
# TCG
# CGT
# GTT
# TTC
# TCA
# CAT
# ATC
# TCA
# CAC
# ACA
# CAT
# ATG
# TGT
# GTG
# TGT
# GTG
# TGT
# GTA
# TAA
# AAC
# ACC
# CCG
# CGA
# GAG
# AGC
# GCA
# CAG
# AGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCC
# CCC
# CCG
# CGG
# GGT
# GTA
# TAG
# AGG
# GGC
# GCT
# CTT
# TTC
# TCA
# CAC
# ACA
# CAC
# ACA
# CAT
# ATG
# TGT
# GTC
# TCG
# CGG
# GGG
# GGG
# GGT
# GTC
# TCA
# CAG
# AGC
# GCA
# CAA
# AAG
# AGC
# GCA
# CAT
# ATC
# TCC
# CCC
# CCG
# CGT
# GTT
# TTC
# TCA
# CAG
# AGA
# GAG
# AGT
# GTA
# TAT
# ATT
# TTC
# TCA
# CAT
# ATG
# TGA
# GAT
# ATC
# TCT
# CTC
# TCC
# CCG
# CGG
# GGG
# GGG
# GGT
# GTG
# TGA
# GAT
# ATA
# TAG
# AGA
# GAC
# ACC
# CCC
# CCA
# CAC
# ACG
# CGG
# GGA
# GAG
# AGC
# GCT
# CTT
# TTC
# TCT
# CTC
# TCC
# CCG
# CGG
# GGC
# GCA
# CAA
# AAG
# AGG
# GGA
# GAC
# ACT
# CTT
# TTC
# TCT
# CTT
# TTG
# TGA
# GAA
# AAT
# ATT
# TTG
# TGG
# GGT
# GTC
# TCT
# CTG
# TGC
# GCC
# CCG
# CGT
# GTC
# TCA
# CAA
# AAC
# ACT
# CTG
# TGA
# GAG
# AGT
# GTG
# TGA
# GAT
# ATC
# TCG
# CGG
# GGC
# GCT
# CTG
# TGT
# GTG
# TGC
# GGC
# GCT
# CTT
# TTA
# TAA
# AAG
# AGT
# GTT
# TTG
# TGT
# GTA
# TAC
# ACA
# CAG
# AGA
# GAA
# AAA
# AAA
# AAC
# ACT
# CTG
# TGG
# GGA
# GAC
# ACA
# CAC
# ACC
# CCA
# CAT
# ATC
# TCG
# CGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAT
# ATA
# TAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TCT
# CTA
# TAA
# AAA
# AAT
# ATC
# TCC
# CCC
# CCG
# CGA
# GAA
# AAT
# ATT
# TTG
# TGC
# GCT
# CTC
# TCA
# CAA
# AAA
# AAG
# AGG
# GGC
# GCG
# CGT
# GTC
# TCT
# CTT
# TTC
# TCA
# CAC
# ACC
# CCA
# CAG
# AGA
# GAG
# AGT
# GTA
# TAC
# ACT
# CTG
# TGG
# GGT
# GTT
# TTC
# TCG
# CGT
# GTA
# TAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAG
# AGT
# GTA
# TAA
# AAG
# AGG
# GGA
# GAA
# AAG
# AGA
# GAT
# ATT
# TTG
# TGC
# GCA
# CAA
# AAC
# ACA
# CAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGC
# GCC
# CCA
# CAT
# ATG
# TGC
# GCT
# CTA
# TAC
# ACT
# CTA
# TAA
# AAG
# AGC
# GCC
# CCG
# CGT
# GTA
# TAA
# AAG
# AGA
# GAT
# ATT
# TTG
# TGC
# GCC
# CCC
# CCA
# CAG
# AGG
# GGA
# GAG
# AGA
# GAT
# ATC
# TCT
# CTG
# TGG
# GGC
# GCC
# CCC
# CCA
# CAA
# AAC
# ACT
# CTT
# TTC
# TCG
# CGT
# GTT
# TTA
# TAA
# AAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATT
# TTG
# TGG
# GGG
# GGA
# GAC
# ACC
# CCA
# CAT
# ATC
# TCA
# CAC
# ACC
# CCT
# CTG
# TGG
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# CAA
# AAG
# AGG
# GGG
# GGG
# GGC
# GCA
# CAC
# ACC
# CCA
# CAT
# ATA
# TAT
# ATC
# TCC
# CCC
# CCT
# CTA
# TAT
# ATG
# TGA
# GAC
# ACC
# CCA
# CAT
# ATG
# TGG
# GGT
# GTC
# TCT
# CTG
# TGA
# GAG
# AGT
# GTC
# TCT
# CTG
# TGG
# GGA
# GAT
# ATA
# TAC
# ACG
# CGT
# GTG
# TGG
# GGA
# GAA
# AAT
# ATG
# TGC
# GCT
# CTA
# TAT
# ATG
# TGC
# GCG
# CGT
# GTG
# TGA
# GAC
# ACA
# CAA
# AAG
# AGG
# GGT
# GTG
# TGA
# GAA
# AAC
# ACT
# CTC
# TCA
# CAA
# AAT
# ATA
# TAG
# AGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAC
# ACG
# CGA
# GAT
# ATC
# TCA
# CAG
# AGC
# GCG
# CGC
# GCT
# CTC
# TCA
# CAA
# AAG
# AGA
# GAC
# ACA
# CAT
# ATA
# TAT
# ATT
# TTA
# TAG
# AGC
# GCA
# CAA
# AAC
# ACG
# CGT
# GTA
# TAC
# ACT
# CTA
# TAC
# ACG
# CGT
# GTT
# TTA
# TAT
# ATC
# TCT
# CTC
# TCT
# CTT
# TTG
# TGG
# GGC
# GCT
# CTC
# TCA
# CAA
# AAG
# AGA
# GAA
# AAA
# AAT
# ATT
# TTC
# TCA
# CAG
# AGA
# GAT
# ATC
# TCA
# CAA
# AAG
# AGC
# GCG
# CGC
# GCA
# CAG
# AGA
# GAA
# AAA
# AAA
# AAG
# AGA
# GAA
# AAA
# AAA
# AAA
# AAT
# ATT
# TTA
# TAC
# ACC
# CCT
# CTT
# TTG
# TGG
# GGC
# GCT
# CTT
# TTA
# TAG
# AGC
# GCG
# CGT
# GTA
# TAA
# AAG
# AGG
# GGG
# GGC
# GCT
# CTG
# TGA
# GAC
# ACT
# CTA
# TAC
# ACC
# CCC
# CCC
# ATG
# TGA
# GAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGG
# GGG
# GGA
# GAC
# ACT
# CTC
# TCA
# CAA
# AAT
# ATA
# TAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATA
# TAC
# ACC
# CCT
# CTC
# TCG
# CGG
# GGA
# GAA
# AAA
# AAG
# AGT
# GTC
# TCT
# CTA
# TAA
# AAA
# AAC
# ACG
# CGA
# GAG
# AGC
# GCA
# CAC
# ACA
# CAT
# ATT
# TTC
# TCT
# CTC
# TCC
# CCT
# CTA
# TAT
# ATT
# TTG
# TGG
# GGC
# GCT
# CTT
# TTG
# TGT
# GTC
# TCG
# CGC
# GCT
# CTA
# TAC
# ACA
# CAT
# ATG
# TGT
# GTA
# TAC
# ACT
# CTC
# TCC
# CCA
# CAT
# ATC
# TCA
# CAA
# AAG
# AGC
# GCG
# CGT
# GTG
# TGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAA
# AAG
# AGA
# GAG
# AGA
# GAA
# AAC
# ACC
# CCT
# CTA
# TAC
# ACC
# CCC
# CCA
# CAT
# ATC
# TCG
# CGA
# GAA
# AAT
# ATA
# TAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTT
# TTG
# TGT
# GTC
# TCC
# CCC
# CCC
# CCA
# CAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACT
# CTA
# TAT
# ATC
# TCT
# CTG
# TGA
# GAC
# ACA
# CAA
# AAC
# ACG
# CGT
# GTG
# TGG
# GGG
# GGT
# GTC
# TCT
# CTC
# TCT
# CTA
# TAT
# ATA
# TAA
# AAA
# AAG
# AGG
# GGA
# GAG
# AGT
# GTC
# TCC
# CCT
# CTG
# TGT
# GTG
# TGG
# GGG
# GGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGC
# GCC
# CCT
# CTG
# TGT
# ATG
# TGA
# GAG
# AGT
# GTG
# TGA
# GAT
# ATA
# TAT
# ATA
# TAG
# AGA
# GAG
# AGT
# GTC
# TCT
# CTG
# TGC
# GCG
# CGT
# GTA
# TAC
# ACC
# CCA
# CAA
# AAA
# AAT
# ATA
# TAG
# AGT
# GTG
# TGT
# GTT
# TTC
# TCC
# CCT
# CTG
# TGT
# GTA
# TAC
# ACC
# CCT
# CTA
# TAT
# ATT
# TTA
# TAG
# AGG
# GGT
# GTG
# TGA
# GAC
# ACA
# CAA
# AAG
# AGT
# GTA
# TAC
# ACA
# CAA
# AAG
# AGA
# GAA
# AAG
# AGG
# GGA
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# GAG
# AGG
# GGC
# GCA
# CAT
# ATT
# TTA
# TAA
# AAC
# ACA
# CAG
# AGC
# GCT
# CTG
# TGA
# GAG
# AGG
# GGG
# GGC
# GCA
# CAC
# ACT
# CTG
# TGC
# GCA
# CAC
# ACG
# CGT
# GTC
# TCA
# CAG
# AGG
# GGA
# GAC
# ACA
# CAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTG
# TGG
# GGG
# GGA
# GAT
# ATA
# TAT
# ATG
# TGC
# GCA
# CAG
# AGT
# GTG
# TGG
# GGA
# GAC
# ACC
# CCC
# CCT
# CTA
# TAC
# ACG
# CGC
# GCA
# CAC
# ACA
# CAC
# ACA
# CAC
# ACA
# CAG
# AGC
# GCA
# CAC
# ACT
# CTA
# TAC
# ACC
# CCA
# CAA
# AAC
# ACA
# CAT
# ATA
# TAG
# AGG
# GGC
# GCT
# CTG
# TGG
# GGG
# GGT
# GTT
# TTA
# TAA
# AAG
# AGG
# GGT
# GTG
# TGT
# GTG
# TGG
# GGG
# GGC
# GCA
# CAA
# AAC
# ACG
# CGG
# GGT
# GTG
# TGG
# GGA
# GAG
# AGA
# GAC
# ACA
# CAA
# AAG
# AGC
# GCG
# CGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAT
# ATC
# TCT
# CTG
# CTA
# TAC
# ACC
# CCT
# CTG
# TGA
# GAA
# AAT
# ATG
# TGC
# GCA
# CAG
# AGA
# GAT
# ATG
# TGG
# GGT
# GTT
# TTC
# TCT
# CTC
# TCT
# CTA
# TAG
# AGG
# GGT
# GTG
# TGA
# GAT
# ATC
# TCA
# CAC
# ACT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGA
# GAG
# AGG
# GGA
# GAT
# ATA
# TAA
# AAT
# ATG
# TGG
# GGA
# GAT
# ATT
# TTC
# TCA
# CAG
# AGT
# GTA
# TAG
# AGA
# GAG
# AGG
# GGC
# GCA
# CAC
# ACA
# CAG
# AGG
# GGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAC
# ACA
# CAA
# AAG
# AGG
# GGA
# GAT
# ATT
# TTC
# TCT
# CTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAG
# AGG
# GGG
# GGG
# GGT
# GTG
# TGA
# GAG
# AGT
# GTC
# TCG
# CGC
# GCT
# CTG
# TGT
# GTA
# TAT
# ATT
# TTT
# TTA
# TAC
# ACC
# CCT
# CTC
# TCG
# CGA
# GAC
# ACC
# CCT
# CTC
# TCC
# CCT
# CTC
# TCA
# CAT
# ATT
# TTG
# TGA
# GAT
# ATA
# TAA
# AAG
# AGT
# GTT
# TTC
# TCT
# CTG
# TGG
# GGA
# GAA
# AAG
# AGG
# GGA
# GAA
# AAG
# AGG
# GGT
# GTT
# TTA
# TAC
# ACC
# CCT
# CTA
# TAA
# AAA
# AAC
# ACC
# CCG
# CGG
# GGG
# GGT
# GTA
# TAA
# AAA
# AAT
# ATC
# TCA
# CAC
# ACC
# CCT
# CTA
# TAT
# ATC
# TCC
# CCA
# CAA
# AAT
# ATG
# TGA
# GAG
# AGA
# GAA
# AAG
# AGT
# GTC
# TCT
# CTG
# TGC
# GCT
# CTA
# TAT
# ATC
# TCT
# CTA
# TAC
# ACA
# CAG
# AGA
# GAT
# ATC
# TGC
# GCT
# CTC
# TCT
# CTA
# TAT
# ATG
# TGG
# GGG
# GGA
# GAT
# ATA
# TAA
# AAT
# ATG
# TGC
# GCA
# CAA
# AAT
# ATG
# TGA
# GAA
# AAT
# ATG
# TGT
# GTG
# TGG
# GGA
# GAT
# ATG
# TGT
# GTA
# TAA
# AAC
# ACA
# CAG
# AGG
# GGG
# GGT
# GTG
# TGA
# GAA
# AAG
# AGT
# GTA
# TAT
# ATG
# TGA
# GAA
# AAA
# AAC
# ACC
# CCA
# CAG
# AGA
# GAA
# AAG
# AGA
# GAT
# ATC
# TCT
# CTA
# TAA
# AAA
# AAG
# AGA
# GAC
# ACC
# CCG
# CGG
# GGG
# GGG
# GGT
# GTA
# TAA
# AAT
# ATC
# TCA
# CAG
# AGG
# GGT
# GTT
# TTC
# TCT
# CTC
# TCC
# CCT
# CTT
# TTA
# TAT
# ATT
# TTT
# TTA
# TAA
# AAG
# AGG
# GGT
# GTT
# TTC
# TCT
# CTA
# TAA
# AAG
# AGA
# GAG
# AGA
# GAT
# ATA
# TAA
# AAA
# AAG
# AGC
# GCA
# CAG
# AGA
# GAG
# AGA
# GAA
# AAG
# AGG
# GGA
# GAA
# AAA
# AAG
# AGC
# GCC
# CCT
# CTG
# TGG
# GGG
# GGT
# GTT
# TTC
# TCA
# CAG
# AGT
# GTT
# TTG
# TGG
# GGT
# GTG
# TGA
# GAT
# ATA
# TAT
# ATG
# TGT
# GTG
# TGG
# GGA
# GAG
# AGA
# GAG
# AGA
# GAG
# AGA
# GAT
# ATG
# TGT
# GTA
# TAT
# ATG
# TGT
# GTC
# TCA
# CAG
# AGA
# GAT
# ATT
# TTC
# TCG
# CGA
# GAC
# ACA
# CAT
# ATA
# TAC
# ACT
# CTC
# TCC
# CCG
# CGA
# GAT
# ATC
# TCT
# CTC
# TCA
# CAT
# ATG
# TGG
# GGA
# GAG
# AGC
# GCC
# CCA
# CAC
# ACA
# CAA
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)
# /tmp/ipykernel_16221/2725726382.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[str(nameSeq)] = propertyfunc(sequence)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
#     df[str(result.name)] = result.curvature[0,:]
#     df[str(result.name)] = df[str(result.name)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[0])
#     df.to_csv(snakemake.output[1], index=True)
# else:
#     plt.savefig(snakemake.output[0])
#     plt.show()
#     df.to_csv(snakemake.output[1], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTodiValues(sequence, 'stability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[1])
#     df.to_csv(snakemake.output[2], index=True)
# else:
#     plt.savefig(snakemake.output[1])
#     plt.show()
#     df.to_csv(snakemake.output[2], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTotriValues(sequence, 'DNAse1_bendability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[3])
#     df.to_csv(snakemake.output[4], index=True)
# else:
#     plt.savefig(snakemake.output[3])
#     plt.show()
#     df.to_csv(snakemake.output[4], index=True)

# %%
# Out:
# LUZ7 t5 plus
