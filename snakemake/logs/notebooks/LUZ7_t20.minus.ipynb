# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/yostrich/anaconda3/envs/snakemake/lib/python3.10/site-packages', '/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95!\x08\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c3TSS_LUZ7_t20/TSS_seq_LUZ7_enriched_t20.minus.fa.out\x94\x8c'TSS_LUZ7_t20/random_seq_LUZ7_t20.fa.out\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x11\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x17)}\x94\x8c\x05_name\x94h\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c?TSS_LUZ7_t20/structural_properties/LUZ7_t20_curvature.minus.csv\x94\x8c?TSS_LUZ7_t20/structural_properties/LUZ7_t20_stability.minus.csv\x94\x8cATSS_LUZ7_t20/structural_properties/LUZ7_t20_bendability.minus.csv\x94\x8cJTSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_curvature.minus.csv\x94\x8cJTSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_stability.minus.csv\x94\x8cLTSS_LUZ7_t20/structural_properties/random_seq_LUZ7_t20_bendability.minus.csv\x94e}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x04LUZ7\x94\x8c\x03t20\x94\x8c\x05minus\x94e}\x94(h\r}\x94(\x8c\x05phage\x94K\x00N\x86\x94\x8c\x05ident\x94K\x01N\x86\x94\x8c\x04sign\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94b\x8c\x05phage\x94hI\x8c\x05ident\x94hJ\x8c\x04sign\x94hKub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bhhK\x01hjK\x01hlheub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c#logs/notebooks/LUZ7_t20.minus.ipynb\x94a}\x94(h\r}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x0f]\x94(h\x11h\x12eh\x11h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x11sNt\x94bh\x12h\x15h\x17\x85\x94R\x94(h\x17)}\x94h\x1bh\x12sNt\x94bh~h{ub\x8c\x06config\x94}\x94(\x8c\nPhage name\x94\x8c\x04LUZ7\x94\x8c\nfasta file\x94\x8c\nLUZ7.fasta\x94\x8c\x0eenriched fastq\x94\x8c\x1ctestData/LUZ7_enriched.fastq\x94\x8c\rcontrol fastq\x94\x8c\x1btestData/LUZ7_control.fastq\x94\x8c\x02ID\x94\x8c\x01a\x94\x8c\rtermseq alpha\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rcluster width\x94}\x94(\x8c\x03TSS\x94K\n\x8c\x03TTS\x94K\x14u\x8c\x10minimum coverage\x94}\x94(\x8c\x03TSS\x94K\x05\x8c\x03TTS\x94K\x1eu\x8c\x14peak alignment error\x94K\x02\x8c\rTSS Threshold\x94K\x01\x8c\rTTS threshold\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x17TSS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94Kdu\x8c\x17TTS sequence extraction\x94}\x94(\x8c\x08upstream\x94Kd\x8c\ndownstream\x94K\x14uu\x8c\x04rule\x94\x8c\x0ecreateNotebook\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake/workflow/rules/../../notebooks\x94ub."); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/mnt/c/Users/danis/Desktop/Thesis/pipeline_snakemake');
######## snakemake preamble end #########

# %%
# dependencies
from dnacurve import CurvedDNA
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
from operator import truediv
from scipy import signal

# %%
def seqTodiValues(seq, property_name):
    diNucTable = pd.read_csv('workflow/tables/dinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-1):
        j = i+2
        value_list.append(diNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0]
def seqTotriValues(seq, property_name):
    triNucTable = pd.read_csv('workflow/tables/trinucleotideTable.csv')
    value_list = []
    for i in range(0,len(seq)-2):
        j = i+3
        print( f"{seq[i:j]}")
        value_list.append(triNucTable.query(f"sequence == '{seq[i:j]}'")[property_name].item())
    return value_list + [0,0]
def getCurvature(seq):
    return CurvedDNA(seq, 'nucleosome').curvature[0,:].tolist()
def savePropertiesToCsv(propertyfunc, fastaFile, window,outCSV,bp_upstream,bp_downstream):
    fasta_sequences = SeqIO.parse(open(fastaFile),'fasta')
    df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
    for fasta in fasta_sequences:
        nameSeq, sequence = fasta.id, str(fasta.seq)
        df[str(nameSeq)] = propertyfunc(sequence)
        df[str(nameSeq)] = df[str(nameSeq)].rolling(window).mean()
    df["mean"] = df.mean(axis=1)
    df.to_csv(outCSV, index=True)

# %%
bp_upstream = -1*snakemake.config["TSS sequence extraction"]["upstream"]
bp_downstream = snakemake.config["TSS sequence extraction"]["downstream"]

# %%
partial_stability = lambda y: seqTodiValues(y, "stability")
partial_bendability = lambda y: seqTotriValues(y, "DNAse1_bendability")
savePropertiesToCsv(getCurvature,snakemake.input[0], 20, snakemake.output[0],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[0], 20, snakemake.output[1],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[0], 20, snakemake.output[2],bp_upstream,bp_downstream)
savePropertiesToCsv(getCurvature,snakemake.input[1], 20, snakemake.output[3],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_stability,snakemake.input[1], 20, snakemake.output[4],bp_upstream,bp_downstream)
savePropertiesToCsv(partial_bendability,snakemake.input[1], 20, snakemake.output[5],bp_upstream,bp_downstream)
# Out:
# CGG
# GGA
# GAA
# AAG
# AGC
# GCT
# CTG
# TGT
# GTG
# TGT
# GTT
# TTG
# TGC
# GCG
# CGG
# GGA
# GAT
# ATC
# TCG
# CGA
# GAC
# ACA
# CAA
# AAG
# AGA
# GAA
# AAC
# ACT
# CTC
# TCG
# CGC
# GCA
# CAG
# AGC
# GCA
# CAG
# AGC
# GCG
# CGT
# GTT
# TTT
# TTG
# TGA
# GAC
# ACC
# CCG
# CGA
# GAA
# AAG
# AGC
# GCC
# CCA
# CAT
# ATG
# TGC
# GCA
# CAG
# AGC
# GCA
# CAG
# AGG
# GGA
# GAT
# ATT
# TTG
# TGA
# GAC
# ACC
# CCT
# CTG
# TGT
# GTC
# TCA
# CAG
# AGA
# GAA
# AAG
# AGA
# GAG
# AGC
# GCT
# CTA
# TAT
# ATG
# TGC
# GCG
# CGA
# GAT
# ATA
# TAG
# AGT
# GTT
# TTC
# TCG
# CGT
# GTT
# TTC
# TCC
# CCG
# CGT
# GTG
# TGG
# GGG
# GGG
# GGT
# GTC
# TCC
# CCG
# CGC
# GCT
# CTC
# TCC
# CCT
# CTT
# TTC
# TCC
# CCC
# CCC
# CCA
# CAT
# ATA
# TAG
# AGG
# GGT
# GTT
# TTT
# TTC
# TCA
# CAT
# ATC
# TCC
# CCA
# CAA
# AAC
# ACC
# CCT
# CTC
# TCA
# CAA
# AAC
# ACC
# CCC
# CCC
# CCC
# CCT
# CTA
# TAC
# ACA
# CAG
# AGG
# GGC
# GCA
# CAT
# ATG
# TGT
# GTC
# TCG
# CGC
# GCT
# CTA
# TAC
# ACC
# CCT
# CTG
# TGT
# GTA
# ...

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = CurvedDNA(sequence, 'trifonov', name=nameSeq)
#     df[str(result.name)] = result.curvature[0,:]
#     df[str(result.name)] = df[str(result.name)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[0])
#     df.to_csv(snakemake.output[1], index=True)
# else:
#     plt.savefig(snakemake.output[0])
#     plt.show()
#     df.to_csv(snakemake.output[1], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-1,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTodiValues(sequence, 'stability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(15).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[1])
#     df.to_csv(snakemake.output[2], index=True)
# else:
#     plt.savefig(snakemake.output[1])
#     plt.show()
#     df.to_csv(snakemake.output[2], index=True)

# %%
# fasta_sequences = SeqIO.parse(open(snakemake.input[0]),'fasta')
# df = pd.DataFrame(index=range(bp_upstream,bp_downstream-2,1))
# for fasta in fasta_sequences:
#     nameSeq, sequence = fasta.id, str(fasta.seq)
#     result = seqTotriValues(sequence, 'DNAse1_bendability')
#     df[str(nameSeq)] = result
#     df[str(nameSeq)] = df[str(nameSeq)].rolling(20).mean()
# df["mean"] = df.mean(axis=1)
# if not(df.empty):
#     df.plot(use_index=True)
#     plt.legend('')
#     plt.savefig(snakemake.output[3])
#     df.to_csv(snakemake.output[4], index=True)
# else:
#     plt.savefig(snakemake.output[3])
#     plt.show()
#     df.to_csv(snakemake.output[4], index=True)

# %%
# Out:
# LUZ7 t5 plus
