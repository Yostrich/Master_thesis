# %% [markdown]
# # LUZ7 summary

# %% [markdown]
# ## number of TSSs

# %% [markdown]
# (n) = n number of new TSSs\
# T5 +: 6(6)| -:0\
# T10 +: 11(5)| -:0\
# T20 +: 9(3)| -:19(19)\
# unique nr of TSSs: 33

# %% [markdown]
# ## (possible) inaccuracies

# %% [markdown]
# Termseq_peaks does not consider the increase in coverage as a peak shown with the blue arrow(control). It does consider the increase in coverage as a peak shown in the black arrow(enriched).  (t20 minus strand)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# peaks of control t20 minus

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# peaks of enriched t20 minus

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LUZ100 summary

# %% [markdown]
# ## number of TSSs

# %% [markdown]
# +: 10 | -: 0

# %% [markdown]
# ## possible inaccuracies

# %% [markdown]
# promising peaks with RPM ratio <1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14-1 summary

# %% [markdown]
# ## number of TSSs

# %% [markdown]
# +: 8 |-: 13

# %% [markdown]
# ## possible inaccuracies

# %% [markdown]
# 2 TSSs when it's probably one. can probably be resolved with choosing higher clustering width. (positive strand:red)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Control has way less reads at pos 822 compared to enriched(reads enriched = reads control x 9.5).The RPM of control is higher than enriched, because control has way less reads in total compared to enriched.(10880 vs 229342)\
# I feel like It'd be hard to find TSSs that usually have a lower number of reads when there's a big difference in total reads.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LUZ19 summary

# %% [markdown]
# ## number of TSSs

# %% [markdown]
# +: 4|-:2

# %% [markdown]
# ## possible inaccuracies

# %% [markdown]
# I think the problem that there are little TSSs is the same as the last point made in 14-1. Very big difference in number of reads.(c:14454,e:294646) and low number of reads at peaks. When looking in IGV, I don't really see potential ones I missed.
